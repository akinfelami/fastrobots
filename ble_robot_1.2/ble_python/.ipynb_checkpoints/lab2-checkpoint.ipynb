# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np
LOG.propagate = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()
# Out:
# 2025-02-10 22:54:15,798 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:81:04:26:a3:64
# 2025-02-10 22:54:18,760 | INFO     |: Connected to c0:81:04:26:a3:64

# %%
ble.disconnect()
# Out:
# 2025-02-04 15:18:09,517 | INFO     |: Disconnected from A1C0DD95-B611-6CFA-AF80-6BCF50487F59

# %%
ble.send_command(CMD.PING, "")

# %%
s = ble.receive_string(ble.uuid['RX_STRING'])
print(s)
# Out:
# PONG

# %%
ble.stop_notify(ble.uuid['RX_STRING'])

# %%
pitch_at_minus_90 = []
minus_90_times = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array).split(",")
    pitch_at_minus_90.append(t_t[0])
    minus_90_times.append(t_t[1])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_DATA, "P")

# %%
print(len(pitch_at_minus_90))
print(
# Out:
# 1000

# %%
plt.plot(np.array(minus_90_times).astype(float), np.array(pitch_at_minus_90).astype(float))

# %%
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array).split(",")
    pitch_at_zero.append(t_t[0])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_DATA, "P")

# %%
print(len(pitch_at_zero))
# Out:
# 1000

# %%
pitch_at_90  = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    pitch_at_90.append(t_t)
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_DATA, "P")

# %%
print(len(pitch_at_minus_90))
# Out:
# 1000

# %%
plt.plot(pitch_at_minus_90)

# %%
pitch_full = pitch_at_minus_90 + pitch_at_zero + pitch_at_90

# %%
import numpy as np
import matplotlib.pyplot as plt 
measured_values = np.array([
    np.array(pitch_at_minus_90).astype(float) ,np.array(pitch_at_zero).astype(float), np.array(pitch_at_90).astype(float)
])
mean_measured_values = np.array([np.mean(measured_values[0]), np.mean(measured_values[1]), np.mean(measured_values[2])])
m = (mean_measured_values[2] - mean_measured_values[0]) / (90 - (-90))
b = mean_measured_values[0] - m * (-90)
print(f"Calibration equation: y = {m}x + {b}")
actual_values = np.array([-90, 0, 90])
calibrated_values = m * actual_values + b
plt.plot(actual_values, mean_measured_values, 'bo', label='Measured values')
plt.plot(actual_values, calibrated_values, 'ro', label='Calibrated values')
plt.plot(actual_values, actual_values, 'k--', label='Ideal values')
plt.xlabel('Actual values')
plt.ylabel('Measured/Calibrated values')
plt.legend()
plt.show()
# Out:
# (3, 1000)
# Calibration equation: y = 0.99484385x + 0.056456500000010124

# %%
measured_values = np.array([
    np.array(pitch_at_minus_90).astype(float) ,np.array(pitch_at_zero).astype(float), np.array(pitch_at_90).astype(float)
])
actual_values = np.array([-90, 0, 90])
RawLow = np.mean(measured_values[0])  
RawHigh = np.mean(measured_values[2])  
ReferenceLow = actual_values[0]       
ReferenceHigh = actual_values[2]     
RawRange = RawHigh - RawLow
ReferenceRange = ReferenceHigh - ReferenceLow
calibrated_values = (((measured_values - RawLow) * ReferenceRange) / RawRange) + ReferenceLow

plt.figure(figsize=(8, 5))
raw_means = [np.mean(group) for group in measured_values]
calibrated_means = [np.mean(group) for group in calibrated_values]
plt.plot(actual_values, actual_values, 'k--', label='Ideal Response')
plt.plot(actual_values, raw_means, 'ro-', label='Actual Response')
plt.plot(actual_values, calibrated_means, 'b^-', label='Calibrated Response')

plt.title("Ideal vs. Actual Response")
plt.xlabel("Measured Parameter (°)")
plt.ylabel("Sensor Output (°)")
plt.xticks(actual_values)
plt.grid(True, alpha=0.3)
plt.legend()

# Annotate calibration points
plt.text(actual_values[0], raw_means[0], f' Raw: {raw_means[0]:.1f}°', ha='right')
plt.text(actual_values[-1], raw_means[-1], f' Raw: {raw_means[-1]:.1f}°', ha='left')

plt.tight_layout()
plt.show()

print(f"Calibration Parameters:")
print(f"Raw Low: {RawLow:.2f} → Reference Low: {ReferenceLow}")
print(f"Raw High: {RawHigh:.2f} → Reference High: {ReferenceHigh}")
print(f"Raw Range: {RawRange:.2f}, Reference Range: {ReferenceRange}")
# Out:
# Calibration Parameters:
# Raw Low: -89.48 → Reference Low: -90
# Raw High: 89.59 → Reference High: 90
# Raw Range: 179.07, Reference Range: 180

# %%
ble.stop_notify(ble.uuid['RX_STRING'])

# %%
roll_at_minus_90 = []
times_minus_90 = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array).split(",")
    roll_at_minus_90.append(t_t[0])
    times_minus_90.append(t_t[1])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_DATA, "R")

# %%
print(len(roll_at_minus_90))
# Out:
# 1000

# %%
roll_at_zero = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    roll_at_zero.append(t_t)
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_DATA, "R")

# %%
print(len(roll_at_zero))
# Out:
# 1000

# %%
roll_at_90 = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    roll_at_90.append(t_t)
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_DATA, "R")

# %%
print(len(roll_at_90))
# Out:
# 1000

# %%
measured_values = np.array([
    np.array(roll_at_minus_90).astype(float) ,np.array(roll_at_zero).astype(float), np.array(roll_at_90).astype(float)
])
actual_values = np.array([-90, 0, 90])
RawLow = np.mean(measured_values[0])  
RawHigh = np.mean(measured_values[2])  
ReferenceLow = actual_values[0]       
ReferenceHigh = actual_values[2]     
RawRange = RawHigh - RawLow
ReferenceRange = ReferenceHigh - ReferenceLow
calibrated_values = (((measured_values - RawLow) * ReferenceRange) / RawRange) + ReferenceLow

plt.figure(figsize=(8, 5))
raw_means = [np.mean(group) for group in measured_values]
calibrated_means = [np.mean(group) for group in calibrated_values]
plt.plot(actual_values, actual_values, 'k--', label='Ideal Response')
plt.plot(actual_values, raw_means, 'ro-', label='Actual Response')
plt.plot(actual_values, calibrated_means, 'b^-', label='Calibrated Response')

plt.title("Ideal vs. Actual Response")
plt.xlabel("Measured Parameter (°)")
plt.ylabel("Sensor Output (°)")
plt.xticks(actual_values)
plt.grid(True, alpha=0.3)
plt.legend()

# Annotate calibration points
plt.text(actual_values[0], raw_means[0], f' Raw: {raw_means[0]:.1f}°', ha='right')
plt.text(actual_values[-1], raw_means[-1], f' Raw: {raw_means[-1]:.1f}°', ha='left')

plt.tight_layout()
plt.show()

print(f"Calibration Parameters:")
print(f"Raw Low: {RawLow:.2f} → Reference Low: {ReferenceLow}")
print(f"Raw High: {RawHigh:.2f} → Reference High: {ReferenceHigh}")
print(f"Raw Range: {RawRange:.2f}, Reference Range: {ReferenceRange}")
# Out:
# Calibration Parameters:
# Raw Low: -89.71 → Reference Low: -90
# Raw High: 89.20 → Reference High: 90
# Raw Range: 178.91, Reference Range: 180

# %% [markdown]
# ## FFT

# %%
results = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    pitch, roll, time = t_t.split(",")
    results.append([time, pitch, roll])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.FFT, "")

# %%
ble.stop_notify(ble.uuid['RX_STRING'])

# %%
print(len(results))
# Out:
# 343

# %%
data_array = np.array([[float(value) for value in row] for row in results])

time = data_array[:, 0] 
pitch = data_array[:, 1] 
roll = data_array[:, 2] 
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1) 
plt.plot(time, pitch,label='Pitch')
plt.title('Pitch vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Pitch [degrees]')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2) 
plt.plot(time, roll, color='r', label='Roll')
plt.title('Roll vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Roll [degrees]')
plt.grid()
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

data_array = np.array([[float(value) for value in row] for row in results])

time = data_array[:, 0] 
pitch = data_array[:, 1] 
roll = data_array[:, 2] 

N = len(time)
T = (time[1] - time[0])/1000

pitch_fft = fft(pitch)
pitch_freqs = fftfreq(N, T)
roll_fft = fft(roll)
roll_freqs = fftfreq(N, T)

plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.plot(pitch_freqs[:N // 2], 2/N*np.abs(pitch_fft)[:N // 2], label='Pitch FFT')
plt.title('FFT of Pitch')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(roll_freqs[:N // 2], 2/N*np.abs(roll_fft)[:N // 2], color='r', label='Roll FFT')
plt.title('FFT of Roll')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %%
## Apply Low pass Filter (try cuttoff of 5Hz)
alpha = 0.38
# Out:
# 2025-02-10 12:09:33,003 | INFO     |: Disconnected from A1C0DD95-B611-6CFA-AF80-6BCF50487F59

# %%
fft_results = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    pitch, roll, pitch_lpf, roll_lpf, time = t_t.split(",")
    fft_results.append([time, pitch, roll, pitch_lpf, roll_lpf])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.FFT_LOW_PASS, "")

# %%
data_array = np.array([[float(value) for value in row] for row in fft_results])

time = data_array[:, 0] 
pitch = data_array[:, 1] 
roll = data_array[:, 2] 

pitch_lpf = data_array[:, 3]
roll_lpf = data_array[:, 4]

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1) 
plt.plot(time, pitch,label='Pitch')
plt.plot(time, pitch_lpf, label='Pitch w/ LPF')
plt.title('Pitch vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Pitch [degrees]')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2) 
plt.plot(time, roll, color='r', label='Roll')
plt.plot(time, roll_lpf, label='Pitch w/ LPF')
plt.title('Roll vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Roll [degrees]')
plt.grid()
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

data_array = np.array([[float(value) for value in row] for row in fft_results])

time = data_array[:, 0] 
pitch = data_array[:, 1] 
roll = data_array[:, 2] 
pitch_lpf = data_array[:, 3]
roll_lpf = data_array[:, 4]

N = len(time)
T = (time[1] - time[0])/1000

pitch_fft = fft(pitch)
pitch_freqs = fftfreq(N, T)
roll_fft = fft(roll)
roll_freqs = fftfreq(N, T)
pitch_lpf_fft = fft(pitch_lpf)
roll_lpf_fft = fft(roll_lpf)

plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.plot(pitch_freqs[:N // 2], 2/N*np.abs(pitch_fft)[:N // 2], label='Pitch FFT')
plt.plot(pitch_freqs[:N // 2], 2/N*np.abs(pitch_lpf_fft)[:N // 2], label='Pitch w/LPF FFT')
plt.title('FFT of Pitch')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(roll_freqs[:N // 2], 2/N*np.abs(roll_fft)[:N // 2], color='r', label='Roll FFT')
plt.plot(roll_freqs[:N // 2], 2/N*np.abs(roll_lpf_fft)[:N // 2], label='Roll w/LPF FFT')
plt.title('FFT of Roll')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gyroscope

# %%
gyr_results = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    gy_pitch, gy_roll, gy_yaw, pitch, roll, pitch_lpf, roll_lpf, time = t_t.split(",")
    gyr_results.append([time, pitch, roll, pitch_lpf, roll_lpf, gy_pitch, gy_roll, gy_yaw])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.GYR, "")

# %%
ble.stop_notify(ble.uuid['RX_STRING'])

# %%
data_array = np.array([[float(value) for value in row] for row in gyr_results])

time = data_array[:, 0] 
pitch = data_array[:, 1] 
roll = data_array[:, 2] 

pitch_lpf = data_array[:, 3]
roll_lpf = data_array[:, 4]

gy_pitch = data_array[:, 5]
gy_roll = data_array[:, 6]
gy_yaw = data_array[:, 7]

plt.figure(figsize=(20, 7))
plt.suptitle('~50Hz', fontsize=16)

plt.subplot(1, 3, 1) 
plt.plot(time, pitch,label='Pitch')
plt.plot(time, pitch_lpf, label="Pitch w/ LPF")
plt.plot(time, gy_pitch, label= "Gyroscope Pitch")
plt.title('Pitch vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Pitch [degrees]')
plt.grid()
plt.legend()

plt.subplot(1, 3, 2) 
plt.plot(time, roll, color='r', label='Roll')
plt.plot(time, roll_lpf, label='Pitch w/ LPF')
plt.plot(time, gy_roll, label="Gyroscope Roll")
plt.title('Roll vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Roll [degrees]')
plt.grid()
plt.legend()


plt.subplot(1, 3, 3) 
plt.plot(time, gy_yaw, label="Gyroscope Yaw")
plt.title('Yaw vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Yaw [degrees]')
plt.grid()
plt.legend()
plt.show()
# Out:
# 2025-02-10 20:39:00,310 | INFO     |: Disconnected from A1C0DD95-B611-6CFA-AF80-6BCF50487F59

# %% [markdown]
# ## Complimentary Filter

# %%
comp_results = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    gy_pitch, gy_roll, pitch, roll, pitch_lpf, roll_lpf, comp_pitch, comp_roll, time = t_t.split(",")
    comp_results.append([time, pitch, roll, pitch_lpf, roll_lpf, gy_pitch, gy_roll, comp_pitch, comp_roll])
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.COMP, "")

# %%
ble.stop_notify(ble.uuid['RX_STRING'])

# %%
data_array = np.array([[float(value) for value in row] for row in comp_results])

time = data_array[:, 0] 
pitch = data_array[:, 1] 
roll = data_array[:, 2] 

pitch_lpf = data_array[:, 3]
roll_lpf = data_array[:, 4]

gy_pitch = data_array[:, 5]
gy_roll = data_array[:, 6]

comp_pitch = data_array[:, 7]
comp_roll = data_array[:, 8]

plt.figure(figsize=(14, 7))
plt.suptitle('~50Hz', fontsize=16)

plt.subplot(1, 2, 1) 
plt.plot(time, pitch,label='Pitch')
plt.plot(time, pitch_lpf, label="Pitch w/ LPF")
plt.plot(time, gy_pitch, label= "Gyroscope Pitch")
plt.plot(time, comp_pitch, label='Complimentary Filter Pitch')
plt.title('Pitch vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Pitch [degrees]')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2) 
plt.plot(time, roll, color='r', label='Roll')
plt.plot(time, roll_lpf, label='Roll w/ LPF')
plt.plot(time, gy_roll, label="Gyroscope Roll")
plt.plot(time, comp_roll, color='b' ,label='Complimentary Filter Roll')
plt.title('Roll vs Time')
plt.xlabel('Time [s]')
plt.ylabel('Roll [degrees]')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Sample Data

# %%
## Speed of sampling
imu_results = []
def notification_handler(uuid, byte_array):
    t_t = ble.bytearray_to_string(byte_array)
    pitch_a, roll_a, pitch_g, roll_g, yaw_g, comp_pitch, comp_roll, time = t_t.split(",")
    imu_results.append(time)
    print(f"Accelerometer : [{pitch_a}, {roll_a}] ,  Gyroscope: [{pitch_g}, {roll_g}, {yaw_g}], Complimnetary Filter : [{comp_pitch}, {comp_roll}]")
ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
ble.send_command(CMD.SEND_IMU_DATA, "")
# Out:
# Accelerometer : [0.000, 0.000] ,  Gyroscope: [0.000, 0.000, 0.000], Complimnetary Filter : [0.000, 0.000]
# Accelerometer : [-1.990, 8.806] ,  Gyroscope: [-0.000, 0.001, 0.000], Complimnetary Filter : [-0.000, 0.000]
# Accelerometer : [-1.368, 9.386] ,  Gyroscope: [0.000, 0.002, 0.000], Complimnetary Filter : [-0.000, 0.001]
# Accelerometer : [-1.211, 9.520] ,  Gyroscope: [0.002, 0.003, 0.003], Complimnetary Filter : [0.000, 0.003]
# Accelerometer : [-1.160, 9.283] ,  Gyroscope: [-0.003, -0.002, 0.019], Complimnetary Filter : [0.002, 0.003]
# Accelerometer : [-1.590, 9.564] ,  Gyroscope: [-0.001, -0.006, 0.009], Complimnetary Filter : [-0.002, -0.002]
# Accelerometer : [-1.177, 9.444] ,  Gyroscope: [-0.001, -0.006, 0.007], Complimnetary Filter : [-0.001, -0.006]
# Accelerometer : [-0.904, 8.812] ,  Gyroscope: [-0.001, 0.001, -0.008], Complimnetary Filter : [-0.001, -0.006]
# Accelerometer : [-1.316, 9.088] ,  Gyroscope: [-0.001, 0.002, -0.012], Complimnetary Filter : [-0.001, 0.001]
# Accelerometer : [-1.384, 8.791] ,  Gyroscope: [0.001, 0.004, -0.007], Complimnetary Filter : [-0.001, 0.002]
# Accelerometer : [-2.005, 8.564] ,  Gyroscope: [0.002, 0.003, -0.014], Complimnetary Filter : [0.001, 0.004]
# Accelerometer : [-1.729, 7.860] ,  Gyroscope: [0.006, 0.006, -0.014], Complimnetary Filter : [0.003, 0.004]
# Accelerometer : [-1.560, 9.017] ,  Gyroscope: [-0.007, 0.007, -0.026], Complimnetary Filter : [0.005, 0.007]
# Accelerometer : [-0.548, 8.896] ,  Gyroscope: [-0.011, 0.001, -0.024], Complimnetary Filter : [-0.007, 0.007]
# Accelerometer : [-0.770, 8.499] ,  Gyroscope: [-0.009, -0.001, -0.017], Complimnetary Filter : [-0.011, 0.002]
# Accelerometer : [-1.110, 9.408] ,  Gyroscope: [-0.011, -0.010, 0.004], Complimnetary Filter : [-0.010, -0.002]
# Accelerometer : [-1.404, 8.773] ,  Gyroscope: [-0.012, -0.008, 0.008], Complimnetary Filter : [-0.012, -0.010]
# Accelerometer : [-1.501, 8.725] ,  Gyroscope: [-0.023, 0.006, 0.015], Complimnetary Filter : [-0.015, -0.008]
# Accelerometer : [-0.657, 8.888] ,  Gyroscope: [-0.022, 0.005, 0.019], Complimnetary Filter : [-0.024, 0.005]
# Accelerometer : [-1.289, 8.900] ,  Gyroscope: [-0.023, 0.000, 0.023], Complimnetary Filter : [-0.025, 0.005]
# Accelerometer : [-0.796, 9.127] ,  Gyroscope: [-0.010, -0.001, 0.020], Complimnetary Filter : [-0.024, 0.000]
# Accelerometer : [-1.267, 8.911] ,  Gyroscope: [-0.010, -0.004, 0.023], Complimnetary Filter : [-0.012, -0.001]
# Accelerometer : [-1.617, 9.320] ,  Gyroscope: [-0.009, -0.009, 0.021], Complimnetary Filter : [-0.011, -0.005]
# Accelerometer : [-1.655, 8.897] ,  Gyroscope: [-0.009, -0.022, 0.032], Complimnetary Filter : [-0.011, -0.011]
# Accelerometer : [-1.330, 9.124] ,  Gyroscope: [-0.001, -0.022, 0.035], Complimnetary Filter : [-0.009, -0.023]
# Accelerometer : [-1.123, 8.919] ,  Gyroscope: [-0.001, -0.032, 0.047], Complimnetary Filter : [-0.002, -0.025]
# Accelerometer : [-0.584, 8.884] ,  Gyroscope: [0.000, -0.034, 0.046], Complimnetary Filter : [-0.001, -0.035]
# Accelerometer : [-1.027, 8.925] ,  Gyroscope: [0.001, -0.034, 0.046], Complimnetary Filter : [0.000, -0.037]
# Accelerometer : [-0.819, 9.178] ,  Gyroscope: [0.010, -0.045, 0.044], Complimnetary Filter : [0.002, -0.039]
# Accelerometer : [-1.485, 9.029] ,  Gyroscope: [0.011, -0.045, 0.044], Complimnetary Filter : [0.010, -0.049]
# Accelerometer : [-1.855, 9.254] ,  Gyroscope: [0.013, -0.046, 0.043], Complimnetary Filter : [0.013, -0.050]
# Accelerometer : [-0.602, 8.674] ,  Gyroscope: [0.033, -0.049, 0.035], Complimnetary Filter : [0.016, -0.051]
# Accelerometer : [-1.152, 9.007] ,  Gyroscope: [0.033, -0.051, 0.036], Complimnetary Filter : [0.035, -0.054]
# Accelerometer : [-1.208, 9.444] ,  Gyroscope: [0.035, -0.050, 0.037], Complimnetary Filter : [0.037, -0.057]
# Accelerometer : [-0.772, 8.573] ,  Gyroscope: [0.035, -0.054, 0.033], Complimnetary Filter : [0.038, -0.056]
# Accelerometer : [-1.350, 8.857] ,  Gyroscope: [0.038, -0.057, 0.035], Complimnetary Filter : [0.039, -0.060]
# Accelerometer : [-1.537, 9.359] ,  Gyroscope: [0.039, -0.059, 0.037], Complimnetary Filter : [0.042, -0.063]
# Accelerometer : [-1.368, 8.933] ,  Gyroscope: [0.038, -0.061, 0.034], Complimnetary Filter : [0.043, -0.066]
# Accelerometer : [-1.798, 9.650] ,  Gyroscope: [0.040, -0.062, 0.037], Complimnetary Filter : [0.043, -0.068]
# Accelerometer : [-1.099, 8.671] ,  Gyroscope: [0.043, -0.067, 0.043], Complimnetary Filter : [0.045, -0.069]
# Accelerometer : [-1.482, 8.797] ,  Gyroscope: [0.043, -0.072, 0.046], Complimnetary Filter : [0.048, -0.075]
# Accelerometer : [-0.656, 9.084] ,  Gyroscope: [0.045, -0.077, 0.046], Complimnetary Filter : [0.048, -0.080]
# Accelerometer : [-1.260, 9.799] ,  Gyroscope: [0.051, -0.101, 0.041], Complimnetary Filter : [0.051, -0.088]
# Accelerometer : [-1.343, 8.789] ,  Gyroscope: [0.054, -0.102, 0.040], Complimnetary Filter : [0.057, -0.110]
# Accelerometer : [-1.425, 8.570] ,  Gyroscope: [0.059, -0.105, 0.043], Complimnetary Filter : [0.060, -0.113]
# Accelerometer : [-0.880, 9.037] ,  Gyroscope: [0.071, -0.114, 0.053], Complimnetary Filter : [0.067, -0.118]
# Accelerometer : [-1.599, 9.027] ,  Gyroscope: [0.071, -0.116, 0.056], Complimnetary Filter : [0.078, -0.126]
# Accelerometer : [-1.734, 8.934] ,  Gyroscope: [0.068, -0.116, 0.052], Complimnetary Filter : [0.079, -0.129]
# Accelerometer : [-1.124, 8.256] ,  Gyroscope: [0.067, -0.116, 0.049], Complimnetary Filter : [0.076, -0.129]
# Accelerometer : [-1.269, 9.220] ,  Gyroscope: [0.069, -0.119, 0.056], Complimnetary Filter : [0.075, -0.129]
# Accelerometer : [-0.440, 9.046] ,  Gyroscope: [0.072, -0.117, 0.056], Complimnetary Filter : [0.076, -0.131]
# Accelerometer : [-0.887, 10.131] ,  Gyroscope: [0.071, -0.118, 0.052], Complimnetary Filter : [0.080, -0.130]
# Accelerometer : [-0.685, 9.426] ,  Gyroscope: [0.075, -0.121, 0.054], Complimnetary Filter : [0.080, -0.131]
# Accelerometer : [-1.432, 9.395] ,  Gyroscope: [0.076, -0.124, 0.060], Complimnetary Filter : [0.083, -0.135]
# Accelerometer : [-0.936, 8.261] ,  Gyroscope: [0.079, -0.130, 0.063], Complimnetary Filter : [0.085, -0.138]
# Accelerometer : [-1.346, 8.541] ,  Gyroscope: [0.078, -0.131, 0.063], Complimnetary Filter : [0.088, -0.144]
# Accelerometer : [-1.513, 9.493] ,  Gyroscope: [0.079, -0.134, 0.064], Complimnetary Filter : [0.087, -0.146]
# Accelerometer : [-1.068, 8.964] ,  Gyroscope: [0.086, -0.148, 0.068], Complimnetary Filter : [0.088, -0.150]
# Accelerometer : [-1.131, 9.063] ,  Gyroscope: [0.087, -0.148, 0.065], Complimnetary Filter : [0.095, -0.163]
# Accelerometer : [-2.074, 9.242] ,  Gyroscope: [0.088, -0.148, 0.063], Complimnetary Filter : [0.097, -0.164]
# Accelerometer : [-0.655, 9.023] ,  Gyroscope: [0.096, -0.157, 0.070], Complimnetary Filter : [0.099, -0.166]
# Accelerometer : [-0.738, 9.400] ,  Gyroscope: [0.099, -0.159, 0.070], Complimnetary Filter : [0.107, -0.174]
# Accelerometer : [-1.472, 9.245] ,  Gyroscope: [0.105, -0.159, 0.072], Complimnetary Filter : [0.110, -0.176]
# Accelerometer : [-1.515, 8.410] ,  Gyroscope: [0.096, -0.161, 0.067], Complimnetary Filter : [0.115, -0.177]
# Accelerometer : [-0.897, 8.240] ,  Gyroscope: [0.094, -0.162, 0.068], Complimnetary Filter : [0.107, -0.179]
# Accelerometer : [-1.232, 8.807] ,  Gyroscope: [0.098, -0.165, 0.059], Complimnetary Filter : [0.105, -0.181]
# Accelerometer : [-1.500, 9.466] ,  Gyroscope: [0.098, -0.166, 0.060], Complimnetary Filter : [0.109, -0.183]
# Accelerometer : [-1.270, 8.798] ,  Gyroscope: [0.097, -0.168, 0.060], Complimnetary Filter : [0.109, -0.185]
# Accelerometer : [-1.058, 9.149] ,  Gyroscope: [0.103, -0.173, 0.063], Complimnetary Filter : [0.109, -0.187]
# Accelerometer : [-1.503, 9.195] ,  Gyroscope: [0.104, -0.174, 0.064], Complimnetary Filter : [0.114, -0.192]
# Accelerometer : [-1.199, 9.059] ,  Gyroscope: [0.104, -0.175, 0.064], Complimnetary Filter : [0.116, -0.193]
# Accelerometer : [-1.342, 8.486] ,  Gyroscope: [0.104, -0.184, 0.056], Complimnetary Filter : [0.116, -0.196]
# Accelerometer : [-1.573, 9.413] ,  Gyroscope: [0.105, -0.187, 0.057], Complimnetary Filter : [0.115, -0.204]
# Accelerometer : [-0.986, 8.329] ,  Gyroscope: [0.103, -0.189, 0.058], Complimnetary Filter : [0.116, -0.208]
# Accelerometer : [-1.318, 8.483] ,  Gyroscope: [0.106, -0.193, 0.064], Complimnetary Filter : [0.115, -0.211]
# Accelerometer : [-2.129, 8.698] ,  Gyroscope: [0.108, -0.195, 0.066], Complimnetary Filter : [0.117, -0.214]
# Accelerometer : [-1.184, 9.122] ,  Gyroscope: [0.109, -0.201, 0.063], Complimnetary Filter : [0.120, -0.217]
# Accelerometer : [-0.719, 8.999] ,  Gyroscope: [0.109, -0.203, 0.063], Complimnetary Filter : [0.121, -0.223]
# Accelerometer : [-0.581, 9.520] ,  Gyroscope: [0.111, -0.205, 0.063], Complimnetary Filter : [0.121, -0.226]
# Accelerometer : [-1.267, 9.099] ,  Gyroscope: [0.110, -0.206, 0.063], Complimnetary Filter : [0.123, -0.228]
# Accelerometer : [-0.992, 8.561] ,  Gyroscope: [0.114, -0.206, 0.063], Complimnetary Filter : [0.123, -0.229]
# Accelerometer : [-1.750, 9.275] ,  Gyroscope: [0.113, -0.206, 0.062], Complimnetary Filter : [0.126, -0.229]
# Accelerometer : [-0.781, 9.136] ,  Gyroscope: [0.104, -0.210, 0.066], Complimnetary Filter : [0.125, -0.229]
# Accelerometer : [-0.460, 8.471] ,  Gyroscope: [0.102, -0.210, 0.068], Complimnetary Filter : [0.116, -0.233]
# Accelerometer : [-0.605, 9.243] ,  Gyroscope: [0.103, -0.207, 0.068], Complimnetary Filter : [0.114, -0.233]
# Accelerometer : [-1.812, 9.096] ,  Gyroscope: [0.107, -0.206, 0.064], Complimnetary Filter : [0.115, -0.231]
# Accelerometer : [-1.271, 9.206] ,  Gyroscope: [0.104, -0.206, 0.063], Complimnetary Filter : [0.118, -0.229]
# Accelerometer : [-1.074, 9.979] ,  Gyroscope: [0.104, -0.207, 0.060], Complimnetary Filter : [0.116, -0.229]
# Accelerometer : [-1.310, 9.970] ,  Gyroscope: [0.106, -0.208, 0.061], Complimnetary Filter : [0.116, -0.230]
# Accelerometer : [-1.555, 9.519] ,  Gyroscope: [0.102, -0.208, 0.053], Complimnetary Filter : [0.117, -0.231]
# Accelerometer : [-1.652, 8.799] ,  Gyroscope: [0.096, -0.207, 0.048], Complimnetary Filter : [0.114, -0.231]
# Accelerometer : [-1.236, 9.208] ,  Gyroscope: [0.094, -0.207, 0.049], Complimnetary Filter : [0.108, -0.230]
# Accelerometer : [-1.399, 7.883] ,  Gyroscope: [0.089, -0.208, 0.047], Complimnetary Filter : [0.104, -0.231]
# Accelerometer : [-1.078, 8.891] ,  Gyroscope: [0.092, -0.210, 0.056], Complimnetary Filter : [0.100, -0.231]
# Accelerometer : [-0.634, 8.915] ,  Gyroscope: [0.093, -0.210, 0.062], Complimnetary Filter : [0.102, -0.233]
# Accelerometer : [-1.445, 9.069] ,  Gyroscope: [0.090, -0.213, 0.068], Complimnetary Filter : [0.103, -0.234]
# Accelerometer : [-1.418, 8.992] ,  Gyroscope: [0.093, -0.212, 0.066], Complimnetary Filter : [0.100, -0.236]
# Accelerometer : [-1.922, 8.955] ,  Gyroscope: [0.095, -0.210, 0.067], Complimnetary Filter : [0.103, -0.236]
# Accelerometer : [-1.579, 9.691] ,  Gyroscope: [0.096, -0.205, 0.074], Complimnetary Filter : [0.106, -0.233]
# Accelerometer : [-0.935, 9.136] ,  Gyroscope: [0.106, -0.202, 0.080], Complimnetary Filter : [0.107, -0.228]
# Accelerometer : [-1.965, 8.208] ,  Gyroscope: [0.107, -0.204, 0.081], Complimnetary Filter : [0.117, -0.225]
# Accelerometer : [-0.962, 8.732] ,  Gyroscope: [0.109, -0.204, 0.081], Complimnetary Filter : [0.119, -0.226]
# Accelerometer : [-1.039, 8.521] ,  Gyroscope: [0.091, -0.207, 0.066], Complimnetary Filter : [0.119, -0.227]
# Accelerometer : [-1.681, 9.607] ,  Gyroscope: [0.089, -0.208, 0.068], Complimnetary Filter : [0.103, -0.230]
# Accelerometer : [-1.674, 8.968] ,  Gyroscope: [0.089, -0.208, 0.068], Complimnetary Filter : [0.099, -0.231]
# Accelerometer : [-1.748, 9.732] ,  Gyroscope: [0.103, -0.208, 0.063], Complimnetary Filter : [0.100, -0.231]
# Accelerometer : [-1.866, 8.556] ,  Gyroscope: [0.106, -0.205, 0.070], Complimnetary Filter : [0.114, -0.231]
# Accelerometer : [-1.591, 9.199] ,  Gyroscope: [0.099, -0.206, 0.063], Complimnetary Filter : [0.117, -0.228]
# Accelerometer : [-1.962, 8.860] ,  Gyroscope: [0.098, -0.207, 0.059], Complimnetary Filter : [0.111, -0.229]
# Accelerometer : [-1.932, 9.090] ,  Gyroscope: [0.098, -0.208, 0.055], Complimnetary Filter : [0.109, -0.230]
# Accelerometer : [-1.331, 9.133] ,  Gyroscope: [0.097, -0.205, 0.058], Complimnetary Filter : [0.109, -0.230]
# Accelerometer : [-1.027, 8.746] ,  Gyroscope: [0.094, -0.209, 0.063], Complimnetary Filter : [0.107, -0.229]
# Accelerometer : [-1.282, 8.881] ,  Gyroscope: [0.095, -0.208, 0.065], Complimnetary Filter : [0.105, -0.232]
# Accelerometer : [-1.819, 8.946] ,  Gyroscope: [0.093, -0.210, 0.064], Complimnetary Filter : [0.105, -0.232]
# Accelerometer : [-1.286, 9.066] ,  Gyroscope: [0.090, -0.212, 0.067], Complimnetary Filter : [0.103, -0.233]
# Accelerometer : [-1.130, 9.319] ,  Gyroscope: [0.097, -0.212, 0.069], Complimnetary Filter : [0.101, -0.235]
# Accelerometer : [-0.645, 9.230] ,  Gyroscope: [0.096, -0.212, 0.070], Complimnetary Filter : [0.107, -0.236]
# Accelerometer : [-0.494, 8.783] ,  Gyroscope: [0.097, -0.210, 0.072], Complimnetary Filter : [0.107, -0.235]
# Accelerometer : [-1.115, 8.985] ,  Gyroscope: [0.097, -0.209, 0.073], Complimnetary Filter : [0.108, -0.233]
# Accelerometer : [-0.471, 8.944] ,  Gyroscope: [0.098, -0.209, 0.072], Complimnetary Filter : [0.108, -0.232]
# Accelerometer : [-1.080, 8.985] ,  Gyroscope: [0.096, -0.216, 0.070], Complimnetary Filter : [0.108, -0.233]
# Accelerometer : [-0.415, 9.776] ,  Gyroscope: [0.089, -0.221, 0.074], Complimnetary Filter : [0.106, -0.240]
# Accelerometer : [-0.644, 9.498] ,  Gyroscope: [0.095, -0.221, 0.079], Complimnetary Filter : [0.100, -0.245]
# Accelerometer : [-0.948, 8.586] ,  Gyroscope: [0.099, -0.223, 0.075], Complimnetary Filter : [0.105, -0.246]
# Accelerometer : [-0.806, 8.716] ,  Gyroscope: [0.098, -0.225, 0.074], Complimnetary Filter : [0.109, -0.248]
# Accelerometer : [-1.277, 9.493] ,  Gyroscope: [0.100, -0.223, 0.079], Complimnetary Filter : [0.109, -0.250]
# Accelerometer : [-0.687, 9.033] ,  Gyroscope: [0.097, -0.221, 0.082], Complimnetary Filter : [0.111, -0.248]
# Accelerometer : [-0.828, 9.686] ,  Gyroscope: [0.088, -0.219, 0.078], Complimnetary Filter : [0.107, -0.246]
# Accelerometer : [-1.097, 10.181] ,  Gyroscope: [0.092, -0.220, 0.076], Complimnetary Filter : [0.099, -0.244]
# Accelerometer : [-1.070, 9.302] ,  Gyroscope: [0.095, -0.222, 0.077], Complimnetary Filter : [0.102, -0.244]
# Accelerometer : [-1.804, 9.191] ,  Gyroscope: [0.092, -0.227, 0.098], Complimnetary Filter : [0.105, -0.247]
# Accelerometer : [-1.657, 8.711] ,  Gyroscope: [0.095, -0.230, 0.102], Complimnetary Filter : [0.103, -0.252]
# Accelerometer : [-1.890, 8.570] ,  Gyroscope: [0.096, -0.235, 0.099], Complimnetary Filter : [0.106, -0.256]
# Accelerometer : [-1.275, 8.725] ,  Gyroscope: [0.104, -0.239, 0.097], Complimnetary Filter : [0.108, -0.261]
# Accelerometer : [-0.956, 8.760] ,  Gyroscope: [0.109, -0.241, 0.097], Complimnetary Filter : [0.115, -0.265]
# Accelerometer : [-1.357, 8.475] ,  Gyroscope: [0.106, -0.244, 0.099], Complimnetary Filter : [0.120, -0.268]
# Accelerometer : [-1.506, 9.475] ,  Gyroscope: [0.105, -0.248, 0.096], Complimnetary Filter : [0.118, -0.271]
# Accelerometer : [-1.295, 9.877] ,  Gyroscope: [0.111, -0.248, 0.089], Complimnetary Filter : [0.117, -0.276]
# Accelerometer : [-0.765, 8.924] ,  Gyroscope: [0.126, -0.257, 0.101], Complimnetary Filter : [0.124, -0.277]
# Accelerometer : [-1.093, 8.470] ,  Gyroscope: [0.122, -0.258, 0.103], Complimnetary Filter : [0.138, -0.285]
# Accelerometer : [-1.670, 9.284] ,  Gyroscope: [0.123, -0.260, 0.107], Complimnetary Filter : [0.136, -0.287]
# Accelerometer : [-0.883, 9.067] ,  Gyroscope: [0.120, -0.258, 0.105], Complimnetary Filter : [0.136, -0.289]
# Accelerometer : [-1.871, 8.822] ,  Gyroscope: [0.118, -0.259, 0.106], Complimnetary Filter : [0.134, -0.287]
# Accelerometer : [-1.917, 8.620] ,  Gyroscope: [0.125, -0.258, 0.110], Complimnetary Filter : [0.132, -0.288]
# Accelerometer : [-1.175, 8.626] ,  Gyroscope: [0.124, -0.258, 0.109], Complimnetary Filter : [0.138, -0.286]
# Accelerometer : [-1.482, 8.636] ,  Gyroscope: [0.124, -0.258, 0.112], Complimnetary Filter : [0.138, -0.286]
# Accelerometer : [-0.923, 9.105] ,  Gyroscope: [0.123, -0.252, 0.131], Complimnetary Filter : [0.138, -0.286]
# Accelerometer : [-1.019, 9.095] ,  Gyroscope: [0.123, -0.255, 0.130], Complimnetary Filter : [0.137, -0.281]
# Accelerometer : [-0.742, 8.894] ,  Gyroscope: [0.124, -0.257, 0.132], Complimnetary Filter : [0.137, -0.283]
# Accelerometer : [-1.920, 8.686] ,  Gyroscope: [0.109, -0.253, 0.137], Complimnetary Filter : [0.136, -0.285]
# Accelerometer : [-0.741, 8.748] ,  Gyroscope: [0.107, -0.252, 0.138], Complimnetary Filter : [0.123, -0.281]
# Accelerometer : [-0.628, 8.600] ,  Gyroscope: [0.110, -0.252, 0.139], Complimnetary Filter : [0.120, -0.280]
# Accelerometer : [-0.938, 9.650] ,  Gyroscope: [0.103, -0.247, 0.130], Complimnetary Filter : [0.122, -0.280]
# Accelerometer : [-1.026, 9.075] ,  Gyroscope: [0.106, -0.248, 0.126], Complimnetary Filter : [0.116, -0.275]
# Accelerometer : [-1.521, 9.634] ,  Gyroscope: [0.107, -0.253, 0.129], Complimnetary Filter : [0.118, -0.276]
# Accelerometer : [-0.960, 8.847] ,  Gyroscope: [0.109, -0.256, 0.131], Complimnetary Filter : [0.120, -0.281]
# Accelerometer : [-1.296, 9.967] ,  Gyroscope: [0.106, -0.257, 0.131], Complimnetary Filter : [0.121, -0.284]
# Accelerometer : [-0.661, 9.444] ,  Gyroscope: [0.108, -0.258, 0.133], Complimnetary Filter : [0.119, -0.285]
# Accelerometer : [-0.553, 9.534] ,  Gyroscope: [0.109, -0.261, 0.141], Complimnetary Filter : [0.120, -0.287]
# Accelerometer : [-1.457, 9.431] ,  Gyroscope: [0.115, -0.257, 0.144], Complimnetary Filter : [0.122, -0.289]
# Accelerometer : [-1.304, 9.137] ,  Gyroscope: [0.112, -0.256, 0.143], Complimnetary Filter : [0.127, -0.286]
# Accelerometer : [-1.628, 9.413] ,  Gyroscope: [0.118, -0.267, 0.151], Complimnetary Filter : [0.125, -0.286]
# Accelerometer : [-1.637, 8.908] ,  Gyroscope: [0.117, -0.267, 0.153], Complimnetary Filter : [0.130, -0.296]
# Accelerometer : [-0.879, 9.636] ,  Gyroscope: [0.119, -0.267, 0.156], Complimnetary Filter : [0.130, -0.296]
# Accelerometer : [-0.385, 9.247] ,  Gyroscope: [0.125, -0.274, 0.164], Complimnetary Filter : [0.132, -0.297]
# Accelerometer : [-1.128, 9.462] ,  Gyroscope: [0.124, -0.274, 0.166], Complimnetary Filter : [0.138, -0.303]
# Accelerometer : [-1.101, 9.305] ,  Gyroscope: [0.124, -0.272, 0.166], Complimnetary Filter : [0.138, -0.304]
# Accelerometer : [-1.256, 8.729] ,  Gyroscope: [0.136, -0.268, 0.174], Complimnetary Filter : [0.139, -0.302]
# Accelerometer : [-0.844, 8.541] ,  Gyroscope: [0.136, -0.265, 0.171], Complimnetary Filter : [0.150, -0.298]
# Accelerometer : [-1.387, 9.214] ,  Gyroscope: [0.135, -0.263, 0.172], Complimnetary Filter : [0.151, -0.294]
# Accelerometer : [-0.882, 9.238] ,  Gyroscope: [0.140, -0.268, 0.173], Complimnetary Filter : [0.151, -0.293]
# Accelerometer : [-1.104, 9.444] ,  Gyroscope: [0.138, -0.272, 0.176], Complimnetary Filter : [0.155, -0.298]
# Accelerometer : [-1.535, 9.217] ,  Gyroscope: [0.139, -0.273, 0.169], Complimnetary Filter : [0.153, -0.302]
# Accelerometer : [-1.229, 8.355] ,  Gyroscope: [0.142, -0.274, 0.168], Complimnetary Filter : [0.155, -0.304]
# Accelerometer : [-1.600, 9.059] ,  Gyroscope: [0.143, -0.276, 0.168], Complimnetary Filter : [0.158, -0.305]
# Accelerometer : [-1.523, 9.117] ,  Gyroscope: [0.151, -0.281, 0.160], Complimnetary Filter : [0.160, -0.307]
# Accelerometer : [-1.586, 8.367] ,  Gyroscope: [0.151, -0.281, 0.165], Complimnetary Filter : [0.167, -0.312]
# Accelerometer : [-1.534, 9.159] ,  Gyroscope: [0.152, -0.278, 0.165], Complimnetary Filter : [0.168, -0.312]
# Accelerometer : [-0.965, 8.974] ,  Gyroscope: [0.146, -0.286, 0.159], Complimnetary Filter : [0.169, -0.310]
# Accelerometer : [-1.296, 8.975] ,  Gyroscope: [0.144, -0.285, 0.157], Complimnetary Filter : [0.162, -0.317]
# Accelerometer : [-0.657, 9.155] ,  Gyroscope: [0.144, -0.286, 0.154], Complimnetary Filter : [0.161, -0.317]
# Accelerometer : [-1.109, 9.079] ,  Gyroscope: [0.150, -0.289, 0.152], Complimnetary Filter : [0.161, -0.318]
# Accelerometer : [-0.081, 8.946] ,  Gyroscope: [0.155, -0.290, 0.149], Complimnetary Filter : [0.166, -0.321]
# Accelerometer : [-0.519, 9.187] ,  Gyroscope: [0.160, -0.289, 0.149], Complimnetary Filter : [0.172, -0.322]
# Accelerometer : [-0.496, 9.005] ,  Gyroscope: [0.162, -0.290, 0.150], Complimnetary Filter : [0.178, -0.321]
# Accelerometer : [-0.137, 9.413] ,  Gyroscope: [0.163, -0.290, 0.150], Complimnetary Filter : [0.180, -0.323]
# Accelerometer : [-1.652, 9.337] ,  Gyroscope: [0.165, -0.291, 0.150], Complimnetary Filter : [0.181, -0.323]
# Accelerometer : [-0.385, 9.457] ,  Gyroscope: [0.169, -0.289, 0.153], Complimnetary Filter : [0.183, -0.323]
# Accelerometer : [-0.761, 9.911] ,  Gyroscope: [0.165, -0.293, 0.154], Complimnetary Filter : [0.187, -0.321]
# Accelerometer : [-0.518, 9.174] ,  Gyroscope: [0.156, -0.304, 0.153], Complimnetary Filter : [0.183, -0.326]
# Accelerometer : [-0.354, 9.333] ,  Gyroscope: [0.154, -0.305, 0.154], Complimnetary Filter : [0.174, -0.337]
# Accelerometer : [-1.511, 9.158] ,  Gyroscope: [0.156, -0.308, 0.150], Complimnetary Filter : [0.172, -0.339]
# Accelerometer : [-1.156, 9.498] ,  Gyroscope: [0.152, -0.321, 0.144], Complimnetary Filter : [0.173, -0.343]
# Accelerometer : [-1.480, 8.785] ,  Gyroscope: [0.156, -0.319, 0.143], Complimnetary Filter : [0.170, -0.355]
# Accelerometer : [-1.303, 8.888] ,  Gyroscope: [0.156, -0.321, 0.143], Complimnetary Filter : [0.173, -0.355]
# Accelerometer : [-0.745, 9.654] ,  Gyroscope: [0.172, -0.325, 0.138], Complimnetary Filter : [0.175, -0.357]
# Accelerometer : [-1.235, 8.587] ,  Gyroscope: [0.168, -0.322, 0.141], Complimnetary Filter : [0.189, -0.360]
# Accelerometer : [-1.218, 9.686] ,  Gyroscope: [0.171, -0.316, 0.145], Complimnetary Filter : [0.187, -0.357]
# Accelerometer : [-1.428, 9.636] ,  Gyroscope: [0.173, -0.317, 0.143], Complimnetary Filter : [0.190, -0.352]
# Accelerometer : [-1.234, 9.515] ,  Gyroscope: [0.172, -0.316, 0.141], Complimnetary Filter : [0.192, -0.352]
# Accelerometer : [-2.103, 9.293] ,  Gyroscope: [0.176, -0.325, 0.145], Complimnetary Filter : [0.191, -0.352]
# Accelerometer : [-0.902, 9.271] ,  Gyroscope: [0.183, -0.329, 0.145], Complimnetary Filter : [0.196, -0.360]
# Accelerometer : [-1.186, 8.951] ,  Gyroscope: [0.187, -0.330, 0.146], Complimnetary Filter : [0.203, -0.365]
# Accelerometer : [-1.999, 8.298] ,  Gyroscope: [0.191, -0.335, 0.155], Complimnetary Filter : [0.208, -0.367]
# Accelerometer : [-1.044, 8.618] ,  Gyroscope: [0.189, -0.338, 0.157], Complimnetary Filter : [0.212, -0.372]
# Accelerometer : [-1.073, 9.113] ,  Gyroscope: [0.192, -0.341, 0.155], Complimnetary Filter : [0.211, -0.375]
# Accelerometer : [-1.046, 9.337] ,  Gyroscope: [0.192, -0.343, 0.156], Complimnetary Filter : [0.213, -0.379]
# Accelerometer : [-1.644, 8.785] ,  Gyroscope: [0.191, -0.345, 0.154], Complimnetary Filter : [0.213, -0.381]
# Accelerometer : [-1.105, 9.179] ,  Gyroscope: [0.190, -0.347, 0.151], Complimnetary Filter : [0.212, -0.383]
# Accelerometer : [-1.020, 9.023] ,  Gyroscope: [0.190, -0.349, 0.154], Complimnetary Filter : [0.212, -0.385]
# Accelerometer : [-1.272, 9.269] ,  Gyroscope: [0.189, -0.350, 0.154], Complimnetary Filter : [0.211, -0.388]
# Accelerometer : [-1.046, 9.466] ,  Gyroscope: [0.194, -0.349, 0.152], Complimnetary Filter : [0.211, -0.389]
# Accelerometer : [-1.582, 9.466] ,  Gyroscope: [0.192, -0.348, 0.153], Complimnetary Filter : [0.215, -0.388]
# Accelerometer : [-1.585, 9.187] ,  Gyroscope: [0.191, -0.345, 0.153], Complimnetary Filter : [0.214, -0.386]
# Accelerometer : [-0.412, 9.047] ,  Gyroscope: [0.180, -0.352, 0.166], Complimnetary Filter : [0.212, -0.385]
# Accelerometer : [-1.212, 8.831] ,  Gyroscope: [0.180, -0.357, 0.169], Complimnetary Filter : [0.201, -0.391]
# Accelerometer : [-1.076, 8.847] ,  Gyroscope: [0.173, -0.356, 0.165], Complimnetary Filter : [0.199, -0.396]
# Accelerometer : [-1.131, 9.332] ,  Gyroscope: [0.175, -0.355, 0.158], Complimnetary Filter : [0.193, -0.396]
# Accelerometer : [-1.350, 9.533] ,  Gyroscope: [0.174, -0.355, 0.152], Complimnetary Filter : [0.194, -0.395]
# Accelerometer : [-1.290, 9.252] ,  Gyroscope: [0.172, -0.361, 0.152], Complimnetary Filter : [0.194, -0.395]
# Accelerometer : [-1.146, 9.072] ,  Gyroscope: [0.174, -0.367, 0.153], Complimnetary Filter : [0.192, -0.401]
# Accelerometer : [-1.585, 9.133] ,  Gyroscope: [0.173, -0.365, 0.158], Complimnetary Filter : [0.193, -0.407]
# Accelerometer : [-0.797, 8.330] ,  Gyroscope: [0.175, -0.362, 0.153], Complimnetary Filter : [0.193, -0.405]
# Accelerometer : [-1.180, 9.177] ,  Gyroscope: [0.180, -0.360, 0.145], Complimnetary Filter : [0.195, -0.402]
# Accelerometer : [-1.237, 8.680] ,  Gyroscope: [0.182, -0.361, 0.145], Complimnetary Filter : [0.200, -0.401]
# Accelerometer : [-1.365, 8.328] ,  Gyroscope: [0.183, -0.363, 0.144], Complimnetary Filter : [0.202, -0.401]
# Accelerometer : [-1.123, 9.239] ,  Gyroscope: [0.191, -0.370, 0.149], Complimnetary Filter : [0.204, -0.404]
# Accelerometer : [-0.987, 9.088] ,  Gyroscope: [0.193, -0.372, 0.148], Complimnetary Filter : [0.212, -0.411]
# Accelerometer : [-0.723, 8.729] ,  Gyroscope: [0.193, -0.373, 0.147], Complimnetary Filter : [0.214, -0.413]
# Accelerometer : [-1.208, 9.364] ,  Gyroscope: [0.193, -0.376, 0.136], Complimnetary Filter : [0.214, -0.415]
# Accelerometer : [-0.886, 8.362] ,  Gyroscope: [0.198, -0.380, 0.134], Complimnetary Filter : [0.215, -0.418]
# Accelerometer : [-0.635, 8.551] ,  Gyroscope: [0.198, -0.380, 0.131], Complimnetary Filter : [0.220, -0.421]
# Accelerometer : [-1.994, 9.255] ,  Gyroscope: [0.203, -0.385, 0.135], Complimnetary Filter : [0.221, -0.423]
# Accelerometer : [-1.687, 8.723] ,  Gyroscope: [0.203, -0.386, 0.133], Complimnetary Filter : [0.225, -0.428]
# Accelerometer : [-1.328, 9.138] ,  Gyroscope: [0.203, -0.389, 0.130], Complimnetary Filter : [0.226, -0.429]
# Accelerometer : [-1.046, 8.876] ,  Gyroscope: [0.202, -0.387, 0.132], Complimnetary Filter : [0.226, -0.431]
# Accelerometer : [-1.650, 8.711] ,  Gyroscope: [0.204, -0.387, 0.132], Complimnetary Filter : [0.225, -0.431]
# Accelerometer : [-0.940, 9.242] ,  Gyroscope: [0.206, -0.387, 0.133], Complimnetary Filter : [0.227, -0.430]
# Accelerometer : [-1.374, 9.266] ,  Gyroscope: [0.208, -0.386, 0.133], Complimnetary Filter : [0.229, -0.430]
# Accelerometer : [-1.698, 8.513] ,  Gyroscope: [0.205, -0.389, 0.129], Complimnetary Filter : [0.230, -0.430]
# Accelerometer : [-1.098, 8.962] ,  Gyroscope: [0.210, -0.392, 0.127], Complimnetary Filter : [0.228, -0.432]
# Accelerometer : [-1.295, 8.184] ,  Gyroscope: [0.209, -0.394, 0.129], Complimnetary Filter : [0.233, -0.436]
# Accelerometer : [-0.768, 9.328] ,  Gyroscope: [0.211, -0.394, 0.130], Complimnetary Filter : [0.232, -0.438]
# Accelerometer : [-1.558, 8.176] ,  Gyroscope: [0.203, -0.399, 0.126], Complimnetary Filter : [0.233, -0.438]
# Accelerometer : [-1.245, 9.264] ,  Gyroscope: [0.204, -0.399, 0.126], Complimnetary Filter : [0.226, -0.443]
# Accelerometer : [-1.130, 8.996] ,  Gyroscope: [0.204, -0.399, 0.123], Complimnetary Filter : [0.227, -0.444]
# Accelerometer : [-1.014, 8.682] ,  Gyroscope: [0.196, -0.389, 0.114], Complimnetary Filter : [0.226, -0.442]
# Accelerometer : [-1.763, 8.480] ,  Gyroscope: [0.191, -0.388, 0.114], Complimnetary Filter : [0.218, -0.433]
# Accelerometer : [-0.888, 9.029] ,  Gyroscope: [0.189, -0.387, 0.111], Complimnetary Filter : [0.212, -0.432]
# Accelerometer : [-0.819, 8.805] ,  Gyroscope: [0.169, -0.394, 0.099], Complimnetary Filter : [0.208, -0.431]
# Accelerometer : [-0.630, 8.678] ,  Gyroscope: [0.164, -0.401, 0.104], Complimnetary Filter : [0.189, -0.438]
# Accelerometer : [-1.168, 8.468] ,  Gyroscope: [0.185, -0.415, 0.135], Complimnetary Filter : [0.185, -0.446]
# Accelerometer : [-0.710, 8.943] ,  Gyroscope: [0.181, -0.415, 0.135], Complimnetary Filter : [0.204, -0.460]
# Accelerometer : [-1.649, 8.971] ,  Gyroscope: [0.182, -0.417, 0.133], Complimnetary Filter : [0.202, -0.461]
# Accelerometer : [-0.939, 8.694] ,  Gyroscope: [0.176, -0.413, 0.137], Complimnetary Filter : [0.201, -0.463]
# Accelerometer : [-1.444, 9.002] ,  Gyroscope: [0.176, -0.415, 0.135], Complimnetary Filter : [0.196, -0.460]
# Accelerometer : [-1.286, 8.986] ,  Gyroscope: [0.176, -0.418, 0.136], Complimnetary Filter : [0.196, -0.461]
# Accelerometer : [-1.879, 8.438] ,  Gyroscope: [0.178, -0.418, 0.137], Complimnetary Filter : [0.196, -0.464]
# Accelerometer : [-1.413, 8.423] ,  Gyroscope: [0.180, -0.420, 0.138], Complimnetary Filter : [0.198, -0.464]
# Accelerometer : [-1.702, 8.775] ,  Gyroscope: [0.188, -0.430, 0.132], Complimnetary Filter : [0.201, -0.467]
# Accelerometer : [-1.320, 9.082] ,  Gyroscope: [0.189, -0.430, 0.131], Complimnetary Filter : [0.209, -0.477]
# Accelerometer : [-1.212, 8.696] ,  Gyroscope: [0.188, -0.430, 0.131], Complimnetary Filter : [0.210, -0.478]
# Accelerometer : [-1.454, 9.413] ,  Gyroscope: [0.201, -0.428, 0.152], Complimnetary Filter : [0.211, -0.478]
# Accelerometer : [-1.018, 8.849] ,  Gyroscope: [0.199, -0.431, 0.148], Complimnetary Filter : [0.222, -0.476]
# Accelerometer : [-1.552, 9.130] ,  Gyroscope: [0.203, -0.433, 0.147], Complimnetary Filter : [0.221, -0.479]
# Accelerometer : [-1.347, 8.975] ,  Gyroscope: [0.204, -0.434, 0.139], Complimnetary Filter : [0.225, -0.481]
# Accelerometer : [-1.339, 8.920] ,  Gyroscope: [0.204, -0.437, 0.137], Complimnetary Filter : [0.227, -0.483]
# Accelerometer : [-0.959, 8.570] ,  Gyroscope: [0.204, -0.440, 0.143], Complimnetary Filter : [0.227, -0.486]
# Accelerometer : [-1.615, 9.284] ,  Gyroscope: [0.205, -0.439, 0.141], Complimnetary Filter : [0.227, -0.489]
# Accelerometer : [-1.271, 9.044] ,  Gyroscope: [0.207, -0.440, 0.138], Complimnetary Filter : [0.228, -0.488]
# Accelerometer : [-1.654, 9.565] ,  Gyroscope: [0.206, -0.440, 0.137], Complimnetary Filter : [0.230, -0.488]
# Accelerometer : [-1.618, 8.632] ,  Gyroscope: [0.208, -0.443, 0.136], Complimnetary Filter : [0.229, -0.489]
# Accelerometer : [-1.627, 8.546] ,  Gyroscope: [0.210, -0.446, 0.137], Complimnetary Filter : [0.232, -0.492]
# Accelerometer : [-1.420, 9.471] ,  Gyroscope: [0.208, -0.452, 0.157], Complimnetary Filter : [0.233, -0.496]
# Accelerometer : [-1.513, 9.768] ,  Gyroscope: [0.207, -0.452, 0.163], Complimnetary Filter : [0.231, -0.501]
# Accelerometer : [-1.912, 7.984] ,  Gyroscope: [0.209, -0.455, 0.170], Complimnetary Filter : [0.230, -0.503]
# Accelerometer : [-2.001, 8.896] ,  Gyroscope: [0.214, -0.459, 0.165], Complimnetary Filter : [0.233, -0.506]
# Accelerometer : [-1.362, 9.108] ,  Gyroscope: [0.215, -0.461, 0.167], Complimnetary Filter : [0.237, -0.510]
# Accelerometer : [-0.857, 9.673] ,  Gyroscope: [0.216, -0.464, 0.170], Complimnetary Filter : [0.239, -0.513]
# Accelerometer : [-1.557, 8.783] ,  Gyroscope: [0.214, -0.463, 0.175], Complimnetary Filter : [0.240, -0.515]
# Accelerometer : [-1.150, 8.723] ,  Gyroscope: [0.210, -0.461, 0.178], Complimnetary Filter : [0.237, -0.514]
# Accelerometer : [-0.772, 9.139] ,  Gyroscope: [0.209, -0.459, 0.172], Complimnetary Filter : [0.234, -0.512]
# Accelerometer : [-1.294, 9.122] ,  Gyroscope: [0.211, -0.461, 0.166], Complimnetary Filter : [0.232, -0.511]
# Accelerometer : [-0.999, 8.867] ,  Gyroscope: [0.211, -0.462, 0.167], Complimnetary Filter : [0.235, -0.512]
# Accelerometer : [-1.040, 9.124] ,  Gyroscope: [0.217, -0.464, 0.161], Complimnetary Filter : [0.235, -0.513]
# Accelerometer : [-0.888, 8.650] ,  Gyroscope: [0.221, -0.466, 0.162], Complimnetary Filter : [0.241, -0.516]
# Accelerometer : [-1.600, 9.070] ,  Gyroscope: [0.224, -0.469, 0.160], Complimnetary Filter : [0.245, -0.518]
# Accelerometer : [-1.128, 8.742] ,  Gyroscope: [0.226, -0.475, 0.157], Complimnetary Filter : [0.249, -0.522]
# Accelerometer : [-0.850, 8.869] ,  Gyroscope: [0.226, -0.477, 0.155], Complimnetary Filter : [0.251, -0.528]
# Accelerometer : [-1.675, 8.886] ,  Gyroscope: [0.227, -0.477, 0.150], Complimnetary Filter : [0.251, -0.529]
# Accelerometer : [-1.153, 9.043] ,  Gyroscope: [0.227, -0.478, 0.156], Complimnetary Filter : [0.252, -0.530]
# Accelerometer : [-0.959, 8.597] ,  Gyroscope: [0.229, -0.478, 0.157], Complimnetary Filter : [0.252, -0.531]
# Accelerometer : [-0.999, 9.300] ,  Gyroscope: [0.227, -0.477, 0.157], Complimnetary Filter : [0.254, -0.531]
# Accelerometer : [-0.388, 9.061] ,  Gyroscope: [0.229, -0.478, 0.159], Complimnetary Filter : [0.253, -0.530]
# Accelerometer : [-1.612, 9.293] ,  Gyroscope: [0.229, -0.476, 0.160], Complimnetary Filter : [0.255, -0.531]
# Accelerometer : [-0.877, 9.564] ,  Gyroscope: [0.229, -0.475, 0.160], Complimnetary Filter : [0.255, -0.529]
# Accelerometer : [-0.579, 8.847] ,  Gyroscope: [0.222, -0.468, 0.179], Complimnetary Filter : [0.253, -0.527]
# Accelerometer : [-1.046, 9.547] ,  Gyroscope: [0.218, -0.470, 0.181], Complimnetary Filter : [0.247, -0.521]
# Accelerometer : [-1.321, 9.520] ,  Gyroscope: [0.217, -0.470, 0.188], Complimnetary Filter : [0.242, -0.522]
# Accelerometer : [-1.514, 9.605] ,  Gyroscope: [0.218, -0.471, 0.183], Complimnetary Filter : [0.242, -0.523]
# Accelerometer : [-1.370, 9.106] ,  Gyroscope: [0.220, -0.472, 0.183], Complimnetary Filter : [0.243, -0.523]
# Accelerometer : [-0.910, 8.812] ,  Gyroscope: [0.225, -0.474, 0.188], Complimnetary Filter : [0.245, -0.525]
# Accelerometer : [-1.571, 9.216] ,  Gyroscope: [0.225, -0.477, 0.191], Complimnetary Filter : [0.249, -0.527]
# Accelerometer : [-1.271, 9.018] ,  Gyroscope: [0.228, -0.475, 0.194], Complimnetary Filter : [0.251, -0.530]
# Accelerometer : [-0.912, 9.260] ,  Gyroscope: [0.229, -0.482, 0.199], Complimnetary Filter : [0.253, -0.529]
# Accelerometer : [-0.768, 9.489] ,  Gyroscope: [0.229, -0.480, 0.201], Complimnetary Filter : [0.254, -0.534]
# Accelerometer : [-1.542, 8.561] ,  Gyroscope: [0.230, -0.479, 0.202], Complimnetary Filter : [0.254, -0.533]
# Accelerometer : [-0.929, 9.617] ,  Gyroscope: [0.217, -0.482, 0.208], Complimnetary Filter : [0.254, -0.533]
# Accelerometer : [-1.105, 8.319] ,  Gyroscope: [0.219, -0.482, 0.209], Complimnetary Filter : [0.243, -0.536]
# Accelerometer : [-1.152, 9.413] ,  Gyroscope: [0.219, -0.482, 0.210], Complimnetary Filter : [0.243, -0.535]
# Accelerometer : [-1.310, 9.205] ,  Gyroscope: [0.220, -0.481, 0.222], Complimnetary Filter : [0.243, -0.535]
# Accelerometer : [-1.225, 9.050] ,  Gyroscope: [0.221, -0.479, 0.226], Complimnetary Filter : [0.245, -0.534]
# Accelerometer : [-0.957, 8.497] ,  Gyroscope: [0.216, -0.479, 0.226], Complimnetary Filter : [0.245, -0.533]
# Accelerometer : [-0.520, 9.897] ,  Gyroscope: [0.238, -0.470, 0.220], Complimnetary Filter : [0.243, -0.531]
# Accelerometer : [-0.855, 8.843] ,  Gyroscope: [0.240, -0.471, 0.222], Complimnetary Filter : [0.263, -0.523]
# Accelerometer : [-1.579, 9.020] ,  Gyroscope: [0.249, -0.470, 0.220], Complimnetary Filter : [0.268, -0.523]
# Accelerometer : [-0.930, 8.447] ,  Gyroscope: [0.248, -0.473, 0.221], Complimnetary Filter : [0.275, -0.523]
# Accelerometer : [-1.618, 9.088] ,  Gyroscope: [0.246, -0.473, 0.220], Complimnetary Filter : [0.275, -0.526]
# Accelerometer : [-1.479, 8.754] ,  Gyroscope: [0.244, -0.485, 0.208], Complimnetary Filter : [0.273, -0.527]
# Accelerometer : [-1.404, 9.015] ,  Gyroscope: [0.247, -0.484, 0.206], Complimnetary Filter : [0.272, -0.538]
# Accelerometer : [-1.511, 9.181] ,  Gyroscope: [0.255, -0.482, 0.206], Complimnetary Filter : [0.275, -0.538]
# Accelerometer : [-0.963, 9.515] ,  Gyroscope: [0.255, -0.482, 0.203], Complimnetary Filter : [0.283, -0.535]
# Accelerometer : [-0.774, 8.783] ,  Gyroscope: [0.256, -0.483, 0.200], Complimnetary Filter : [0.283, -0.536]
# Accelerometer : [-1.238, 9.332] ,  Gyroscope: [0.247, -0.484, 0.193], Complimnetary Filter : [0.284, -0.537]
# Accelerometer : [-0.907, 9.082] ,  Gyroscope: [0.248, -0.488, 0.193], Complimnetary Filter : [0.275, -0.538]
# Accelerometer : [-1.537, 8.931] ,  Gyroscope: [0.247, -0.488, 0.190], Complimnetary Filter : [0.275, -0.542]
# Accelerometer : [-1.498, 8.229] ,  Gyroscope: [0.248, -0.484, 0.193], Complimnetary Filter : [0.274, -0.541]
# Accelerometer : [-0.994, 8.878] ,  Gyroscope: [0.247, -0.483, 0.195], Complimnetary Filter : [0.276, -0.538]
# Accelerometer : [-2.086, 8.607] ,  Gyroscope: [0.246, -0.481, 0.200], Complimnetary Filter : [0.274, -0.537]
# Accelerometer : [-1.187, 9.927] ,  Gyroscope: [0.245, -0.484, 0.198], Complimnetary Filter : [0.273, -0.536]
# Accelerometer : [-1.315, 8.566] ,  Gyroscope: [0.249, -0.488, 0.199], Complimnetary Filter : [0.273, -0.538]
# Accelerometer : [-2.260, 8.947] ,  Gyroscope: [0.245, -0.488, 0.193], Complimnetary Filter : [0.276, -0.542]
# Accelerometer : [-1.070, 9.034] ,  Gyroscope: [0.244, -0.483, 0.193], Complimnetary Filter : [0.273, -0.541]
# Accelerometer : [-1.404, 9.256] ,  Gyroscope: [0.248, -0.484, 0.189], Complimnetary Filter : [0.272, -0.537]
# Accelerometer : [-1.275, 9.175] ,  Gyroscope: [0.244, -0.487, 0.192], Complimnetary Filter : [0.274, -0.538]
# Accelerometer : [-1.746, 9.453] ,  Gyroscope: [0.237, -0.485, 0.196], Complimnetary Filter : [0.271, -0.540]
# Accelerometer : [-0.654, 9.223] ,  Gyroscope: [0.234, -0.487, 0.194], Complimnetary Filter : [0.264, -0.540]
# Accelerometer : [-1.260, 8.785] ,  Gyroscope: [0.231, -0.486, 0.194], Complimnetary Filter : [0.260, -0.541]
# Accelerometer : [-1.051, 9.111] ,  Gyroscope: [0.233, -0.487, 0.195], Complimnetary Filter : [0.257, -0.540]
# Accelerometer : [-1.133, 9.345] ,  Gyroscope: [0.236, -0.483, 0.200], Complimnetary Filter : [0.259, -0.540]
# Accelerometer : [-0.762, 8.909] ,  Gyroscope: [0.230, -0.486, 0.208], Complimnetary Filter : [0.262, -0.537]
# Accelerometer : [-1.647, 9.792] ,  Gyroscope: [0.229, -0.488, 0.211], Complimnetary Filter : [0.256, -0.540]
# Accelerometer : [-1.513, 8.979] ,  Gyroscope: [0.231, -0.484, 0.209], Complimnetary Filter : [0.255, -0.541]
# Accelerometer : [-0.844, 8.834] ,  Gyroscope: [0.234, -0.485, 0.210], Complimnetary Filter : [0.257, -0.539]
# Accelerometer : [-1.807, 7.919] ,  Gyroscope: [0.229, -0.483, 0.215], Complimnetary Filter : [0.259, -0.539]
# Accelerometer : [-0.926, 8.971] ,  Gyroscope: [0.229, -0.490, 0.224], Complimnetary Filter : [0.255, -0.538]
# Accelerometer : [-0.663, 8.536] ,  Gyroscope: [0.232, -0.493, 0.220], Complimnetary Filter : [0.255, -0.544]
# Accelerometer : [-1.783, 9.653] ,  Gyroscope: [0.229, -0.495, 0.222], Complimnetary Filter : [0.257, -0.548]
# Accelerometer : [-0.885, 9.003] ,  Gyroscope: [0.224, -0.491, 0.217], Complimnetary Filter : [0.255, -0.549]
# Accelerometer : [-1.125, 8.851] ,  Gyroscope: [0.229, -0.490, 0.214], Complimnetary Filter : [0.250, -0.546]
# Accelerometer : [-0.656, 8.256] ,  Gyroscope: [0.230, -0.491, 0.207], Complimnetary Filter : [0.254, -0.545]
# Accelerometer : [-0.933, 8.935] ,  Gyroscope: [0.230, -0.491, 0.207], Complimnetary Filter : [0.255, -0.546]
# Accelerometer : [-0.879, 8.568] ,  Gyroscope: [0.229, -0.489, 0.206], Complimnetary Filter : [0.256, -0.546]
# Accelerometer : [-1.278, 7.840] ,  Gyroscope: [0.235, -0.497, 0.204], Complimnetary Filter : [0.255, -0.545]
# Accelerometer : [-1.585, 9.537] ,  Gyroscope: [0.236, -0.502, 0.200], Complimnetary Filter : [0.261, -0.552]
# Accelerometer : [-1.202, 8.894] ,  Gyroscope: [0.236, -0.507, 0.200], Complimnetary Filter : [0.263, -0.558]
# Accelerometer : [-0.852, 9.426] ,  Gyroscope: [0.232, -0.511, 0.211], Complimnetary Filter : [0.262, -0.563]
# Accelerometer : [-0.795, 8.548] ,  Gyroscope: [0.228, -0.509, 0.210], Complimnetary Filter : [0.258, -0.567]
# Accelerometer : [-1.458, 9.113] ,  Gyroscope: [0.224, -0.505, 0.209], Complimnetary Filter : [0.254, -0.565]
# Accelerometer : [-0.964, 9.551] ,  Gyroscope: [0.223, -0.505, 0.217], Complimnetary Filter : [0.249, -0.562]
# Accelerometer : [-0.937, 9.131] ,  Gyroscope: [0.223, -0.502, 0.213], Complimnetary Filter : [0.248, -0.561]
# Accelerometer : [-1.669, 9.728] ,  Gyroscope: [0.221, -0.499, 0.208], Complimnetary Filter : [0.248, -0.558]
# Accelerometer : [-1.756, 9.252] ,  Gyroscope: [0.221, -0.494, 0.211], Complimnetary Filter : [0.246, -0.554]
# Accelerometer : [-1.071, 8.962] ,  Gyroscope: [0.219, -0.494, 0.212], Complimnetary Filter : [0.246, -0.549]
# Accelerometer : [-1.329, 8.433] ,  Gyroscope: [0.219, -0.494, 0.209], Complimnetary Filter : [0.244, -0.549]
# Accelerometer : [-1.287, 8.432] ,  Gyroscope: [0.242, -0.493, 0.208], Complimnetary Filter : [0.246, -0.549]
# Accelerometer : [-1.241, 9.027] ,  Gyroscope: [0.243, -0.494, 0.207], Complimnetary Filter : [0.267, -0.548]
# Accelerometer : [-1.093, 9.213] ,  Gyroscope: [0.243, -0.495, 0.210], Complimnetary Filter : [0.270, -0.549]
# Accelerometer : [-1.291, 8.783] ,  Gyroscope: [0.241, -0.495, 0.213], Complimnetary Filter : [0.270, -0.550]
# Accelerometer : [-1.206, 8.999] ,  Gyroscope: [0.240, -0.493, 0.219], Complimnetary Filter : [0.268, -0.550]
# Accelerometer : [-1.287, 8.884] ,  Gyroscope: [0.241, -0.490, 0.221], Complimnetary Filter : [0.267, -0.548]
# Accelerometer : [-0.513, 8.843] ,  Gyroscope: [0.246, -0.491, 0.215], Complimnetary Filter : [0.268, -0.545]
# Accelerometer : [-0.970, 9.124] ,  Gyroscope: [0.250, -0.492, 0.216], Complimnetary Filter : [0.274, -0.546]
# Accelerometer : [-1.881, 8.002] ,  Gyroscope: [0.251, -0.497, 0.226], Complimnetary Filter : [0.277, -0.547]
# Accelerometer : [-1.301, 8.904] ,  Gyroscope: [0.252, -0.497, 0.223], Complimnetary Filter : [0.279, -0.551]
# Accelerometer : [-0.358, 9.372] ,  Gyroscope: [0.251, -0.495, 0.225], Complimnetary Filter : [0.280, -0.552]
# Accelerometer : [-1.300, 8.864] ,  Gyroscope: [0.257, -0.499, 0.229], Complimnetary Filter : [0.279, -0.551]
# Accelerometer : [-0.763, 9.055] ,  Gyroscope: [0.257, -0.497, 0.228], Complimnetary Filter : [0.285, -0.554]
# Accelerometer : [-0.964, 9.149] ,  Gyroscope: [0.258, -0.499, 0.228], Complimnetary Filter : [0.285, -0.553]
# Accelerometer : [-1.542, 8.642] ,  Gyroscope: [0.264, -0.503, 0.241], Complimnetary Filter : [0.287, -0.555]
# Accelerometer : [-1.416, 9.466] ,  Gyroscope: [0.265, -0.502, 0.239], Complimnetary Filter : [0.293, -0.558]
# Accelerometer : [-1.146, 8.512] ,  Gyroscope: [0.265, -0.503, 0.237], Complimnetary Filter : [0.295, -0.558]
# Accelerometer : [-2.347, 9.338] ,  Gyroscope: [0.274, -0.510, 0.232], Complimnetary Filter : [0.296, -0.559]
# Accelerometer : [-1.667, 9.564] ,  Gyroscope: [0.275, -0.509, 0.231], Complimnetary Filter : [0.304, -0.566]
# Accelerometer : [-0.911, 9.493] ,  Gyroscope: [0.278, -0.510, 0.232], Complimnetary Filter : [0.305, -0.566]
# Accelerometer : [-1.265, 9.002] ,  Gyroscope: [0.268, -0.512, 0.224], Complimnetary Filter : [0.307, -0.567]
# Accelerometer : [-1.258, 9.409] ,  Gyroscope: [0.265, -0.510, 0.226], Complimnetary Filter : [0.299, -0.568]
# Accelerometer : [-1.092, 9.661] ,  Gyroscope: [0.263, -0.508, 0.230], Complimnetary Filter : [0.295, -0.567]
# Accelerometer : [-1.598, 8.484] ,  Gyroscope: [0.267, -0.505, 0.224], Complimnetary Filter : [0.293, -0.565]
# Accelerometer : [-0.991, 8.553] ,  Gyroscope: [0.267, -0.503, 0.226], Complimnetary Filter : [0.296, -0.561]
# Accelerometer : [-1.303, 9.187] ,  Gyroscope: [0.269, -0.503, 0.222], Complimnetary Filter : [0.297, -0.559]
# Accelerometer : [-1.374, 9.880] ,  Gyroscope: [0.267, -0.503, 0.220], Complimnetary Filter : [0.298, -0.559]
# Accelerometer : [-0.938, 9.197] ,  Gyroscope: [0.266, -0.505, 0.219], Complimnetary Filter : [0.297, -0.559]
# Accelerometer : [-1.257, 9.612] ,  Gyroscope: [0.270, -0.502, 0.216], Complimnetary Filter : [0.297, -0.560]
# Accelerometer : [-1.979, 8.975] ,  Gyroscope: [0.268, -0.501, 0.215], Complimnetary Filter : [0.299, -0.558]
# Accelerometer : [-0.940, 9.968] ,  Gyroscope: [0.270, -0.501, 0.215], Complimnetary Filter : [0.298, -0.557]
# Accelerometer : [-1.066, 9.195] ,  Gyroscope: [0.272, -0.493, 0.205], Complimnetary Filter : [0.300, -0.556]
# Accelerometer : [-0.818, 9.280] ,  Gyroscope: [0.275, -0.492, 0.209], Complimnetary Filter : [0.302, -0.549]
# Accelerometer : [-1.875, 9.269] ,  Gyroscope: [0.275, -0.494, 0.213], Complimnetary Filter : [0.305, -0.547]
# Accelerometer : [-1.286, 9.226] ,  Gyroscope: [0.277, -0.497, 0.212], Complimnetary Filter : [0.306, -0.549]
# Accelerometer : [-1.474, 8.778] ,  Gyroscope: [0.274, -0.501, 0.208], Complimnetary Filter : [0.307, -0.552]
# Accelerometer : [-1.548, 8.918] ,  Gyroscope: [0.277, -0.502, 0.201], Complimnetary Filter : [0.305, -0.556]
# Accelerometer : [-0.987, 9.275] ,  Gyroscope: [0.280, -0.501, 0.197], Complimnetary Filter : [0.308, -0.557]
# Accelerometer : [-1.535, 9.164] ,  Gyroscope: [0.282, -0.500, 0.198], Complimnetary Filter : [0.311, -0.557]
# Accelerometer : [-1.810, 8.873] ,  Gyroscope: [0.282, -0.499, 0.199], Complimnetary Filter : [0.313, -0.556]
# Accelerometer : [-1.845, 8.941] ,  Gyroscope: [0.283, -0.500, 0.204], Complimnetary Filter : [0.314, -0.555]
# Accelerometer : [-0.691, 9.345] ,  Gyroscope: [0.280, -0.495, 0.201], Complimnetary Filter : [0.314, -0.555]
# Accelerometer : [-0.766, 8.451] ,  Gyroscope: [0.275, -0.497, 0.204], Complimnetary Filter : [0.310, -0.551]
# Accelerometer : [-1.151, 9.373] ,  Gyroscope: [0.274, -0.503, 0.205], Complimnetary Filter : [0.306, -0.553]
# Accelerometer : [-0.801, 9.498] ,  Gyroscope: [0.275, -0.506, 0.206], Complimnetary Filter : [0.304, -0.558]
# Accelerometer : [-0.823, 9.248] ,  Gyroscope: [0.279, -0.514, 0.207], Complimnetary Filter : [0.306, -0.563]
# Accelerometer : [-0.795, 9.217] ,  Gyroscope: [0.279, -0.514, 0.204], Complimnetary Filter : [0.310, -0.571]
# Accelerometer : [-1.901, 8.511] ,  Gyroscope: [0.280, -0.515, 0.203], Complimnetary Filter : [0.310, -0.571]
# Accelerometer : [-0.873, 8.748] ,  Gyroscope: [0.285, -0.520, 0.207], Complimnetary Filter : [0.311, -0.573]
# Accelerometer : [-1.393, 8.943] ,  Gyroscope: [0.286, -0.522, 0.206], Complimnetary Filter : [0.316, -0.578]
# Accelerometer : [-1.248, 9.376] ,  Gyroscope: [0.287, -0.523, 0.206], Complimnetary Filter : [0.318, -0.580]
# Accelerometer : [-1.503, 9.084] ,  Gyroscope: [0.290, -0.529, 0.219], Complimnetary Filter : [0.319, -0.582]
# Accelerometer : [-1.407, 9.869] ,  Gyroscope: [0.296, -0.532, 0.220], Complimnetary Filter : [0.322, -0.587]
# Accelerometer : [-1.212, 9.422] ,  Gyroscope: [0.298, -0.538, 0.219], Complimnetary Filter : [0.329, -0.592]
# Accelerometer : [-1.427, 9.230] ,  Gyroscope: [0.297, -0.541, 0.214], Complimnetary Filter : [0.331, -0.597]
# Accelerometer : [-1.567, 9.029] ,  Gyroscope: [0.296, -0.541, 0.218], Complimnetary Filter : [0.330, -0.601]
# Accelerometer : [-1.740, 9.223] ,  Gyroscope: [0.298, -0.544, 0.220], Complimnetary Filter : [0.329, -0.601]
# Accelerometer : [-1.132, 9.309] ,  Gyroscope: [0.297, -0.545, 0.219], Complimnetary Filter : [0.331, -0.604]
# Accelerometer : [-0.493, 9.164] ,  Gyroscope: [0.299, -0.547, 0.217], Complimnetary Filter : [0.331, -0.605]
# Accelerometer : [-1.542, 8.884] ,  Gyroscope: [0.306, -0.555, 0.219], Complimnetary Filter : [0.333, -0.608]
# Accelerometer : [-1.154, 8.376] ,  Gyroscope: [0.309, -0.554, 0.216], Complimnetary Filter : [0.340, -0.616]
# Accelerometer : [-1.077, 8.852] ,  Gyroscope: [0.312, -0.554, 0.213], Complimnetary Filter : [0.343, -0.616]
# Accelerometer : [-1.521, 8.567] ,  Gyroscope: [0.314, -0.545, 0.210], Complimnetary Filter : [0.346, -0.615]
# Accelerometer : [-0.656, 9.306] ,  Gyroscope: [0.317, -0.542, 0.211], Complimnetary Filter : [0.349, -0.606]
# Accelerometer : [-1.409, 9.157] ,  Gyroscope: [0.317, -0.543, 0.211], Complimnetary Filter : [0.352, -0.603]
# Accelerometer : [-0.931, 8.803] ,  Gyroscope: [0.318, -0.544, 0.215], Complimnetary Filter : [0.353, -0.603]
# Accelerometer : [-1.098, 9.145] ,  Gyroscope: [0.318, -0.546, 0.212], Complimnetary Filter : [0.353, -0.604]
# Accelerometer : [-1.098, 9.310] ,  Gyroscope: [0.322, -0.549, 0.208], Complimnetary Filter : [0.354, -0.606]
# Accelerometer : [-0.985, 9.071] ,  Gyroscope: [0.325, -0.551, 0.212], Complimnetary Filter : [0.358, -0.610]
# Accelerometer : [-1.138, 9.547] ,  Gyroscope: [0.319, -0.553, 0.214], Complimnetary Filter : [0.360, -0.613]
# Accelerometer : [-1.564, 9.600] ,  Gyroscope: [0.320, -0.558, 0.210], Complimnetary Filter : [0.356, -0.615]
# Accelerometer : [-1.234, 9.030] ,  Gyroscope: [0.319, -0.560, 0.214], Complimnetary Filter : [0.355, -0.620]
# Accelerometer : [-1.876, 8.958] ,  Gyroscope: [0.319, -0.562, 0.217], Complimnetary Filter : [0.354, -0.623]
# Accelerometer : [-1.691, 8.828] ,  Gyroscope: [0.318, -0.571, 0.215], Complimnetary Filter : [0.354, -0.625]
# Accelerometer : [-1.241, 8.974] ,  Gyroscope: [0.318, -0.571, 0.217], Complimnetary Filter : [0.353, -0.633]
# ...
# Accelerometer : [-1.089, 9.152] ,  Gyroscope: [1.370, -1.862, 0.287], Complimnetary Filter : [1.519, -2.067]
# Accelerometer : [-1.180, 9.257] ,  Gyroscope: [1.375, -1.863, 0.288], Complimnetary Filter : [1.522, -2.069]
# Accelerometer : [-0.411, 9.208] ,  Gyroscope: [1.376, -1.867, 0.286], Complimnetary Filter : [1.527, -2.070]
# Accelerometer : [-1.282, 8.694] ,  Gyroscope: [1.374, -1.865, 0.282], Complimnetary Filter : [1.529, -2.074]
# Accelerometer : [-1.274, 8.800] ,  Gyroscope: [1.370, -1.863, 0.281], Complimnetary Filter : [1.526, -2.072]
# Accelerometer : [-1.401, 8.913] ,  Gyroscope: [1.370, -1.858, 0.295], Complimnetary Filter : [1.523, -2.070]
# Accelerometer : [-0.992, 8.669] ,  Gyroscope: [1.365, -1.859, 0.291], Complimnetary Filter : [1.522, -2.065]
# Accelerometer : [-0.683, 8.836] ,  Gyroscope: [1.365, -1.858, 0.295], Complimnetary Filter : [1.517, -2.065]
# Accelerometer : [-1.322, 8.992] ,  Gyroscope: [1.366, -1.852, 0.270], Complimnetary Filter : [1.517, -2.064]
# Accelerometer : [-1.046, 9.283] ,  Gyroscope: [1.365, -1.852, 0.278], Complimnetary Filter : [1.517, -2.059]
# Accelerometer : [-0.784, 8.992] ,  Gyroscope: [1.364, -1.853, 0.292], Complimnetary Filter : [1.517, -2.058]
# Accelerometer : [-1.454, 9.038] ,  Gyroscope: [1.369, -1.856, 0.292], Complimnetary Filter : [1.516, -2.059]
# Accelerometer : [-1.101, 9.095] ,  Gyroscope: [1.368, -1.860, 0.293], Complimnetary Filter : [1.520, -2.063]
# Accelerometer : [-1.268, 9.350] ,  Gyroscope: [1.371, -1.859, 0.290], Complimnetary Filter : [1.520, -2.066]
# Accelerometer : [-1.427, 8.775] ,  Gyroscope: [1.373, -1.861, 0.285], Complimnetary Filter : [1.523, -2.066]
# Accelerometer : [-1.268, 9.135] ,  Gyroscope: [1.380, -1.858, 0.284], Complimnetary Filter : [1.526, -2.068]
# Accelerometer : [-1.407, 9.520] ,  Gyroscope: [1.379, -1.857, 0.280], Complimnetary Filter : [1.532, -2.065]
# Accelerometer : [-1.594, 9.216] ,  Gyroscope: [1.378, -1.858, 0.285], Complimnetary Filter : [1.532, -2.064]
# Accelerometer : [-1.343, 8.601] ,  Gyroscope: [1.379, -1.860, 0.286], Complimnetary Filter : [1.531, -2.064]
# Accelerometer : [-1.543, 9.050] ,  Gyroscope: [1.383, -1.861, 0.283], Complimnetary Filter : [1.533, -2.067]
# Accelerometer : [-1.928, 9.261] ,  Gyroscope: [1.381, -1.862, 0.283], Complimnetary Filter : [1.536, -2.068]
# Accelerometer : [-1.445, 9.063] ,  Gyroscope: [1.379, -1.867, 0.290], Complimnetary Filter : [1.534, -2.069]
# Accelerometer : [-0.634, 9.085] ,  Gyroscope: [1.380, -1.870, 0.291], Complimnetary Filter : [1.533, -2.074]
# Accelerometer : [-1.409, 8.721] ,  Gyroscope: [1.381, -1.874, 0.285], Complimnetary Filter : [1.533, -2.078]
# Accelerometer : [-1.480, 8.843] ,  Gyroscope: [1.381, -1.879, 0.277], Complimnetary Filter : [1.535, -2.083]
# Accelerometer : [-1.673, 9.088] ,  Gyroscope: [1.386, -1.878, 0.277], Complimnetary Filter : [1.535, -2.087]
# Accelerometer : [-1.673, 9.195] ,  Gyroscope: [1.385, -1.883, 0.273], Complimnetary Filter : [1.539, -2.088]
# Accelerometer : [-1.399, 8.873] ,  Gyroscope: [1.388, -1.874, 0.275], Complimnetary Filter : [1.539, -2.090]
# Accelerometer : [-1.164, 9.210] ,  Gyroscope: [1.387, -1.876, 0.278], Complimnetary Filter : [1.542, -2.083]
# Accelerometer : [-1.279, 8.967] ,  Gyroscope: [1.388, -1.876, 0.279], Complimnetary Filter : [1.541, -2.084]
# Accelerometer : [-1.785, 9.288] ,  Gyroscope: [1.383, -1.872, 0.286], Complimnetary Filter : [1.541, -2.084]
# Accelerometer : [-1.133, 9.910] ,  Gyroscope: [1.386, -1.874, 0.288], Complimnetary Filter : [1.538, -2.081]
# Accelerometer : [-1.125, 8.533] ,  Gyroscope: [1.388, -1.877, 0.290], Complimnetary Filter : [1.540, -2.082]
# Accelerometer : [-1.578, 8.856] ,  Gyroscope: [1.392, -1.883, 0.292], Complimnetary Filter : [1.543, -2.086]
# Accelerometer : [-0.741, 9.038] ,  Gyroscope: [1.392, -1.881, 0.292], Complimnetary Filter : [1.547, -2.091]
# Accelerometer : [-1.344, 9.302] ,  Gyroscope: [1.391, -1.879, 0.298], Complimnetary Filter : [1.547, -2.090]
# Accelerometer : [-0.714, 9.529] ,  Gyroscope: [1.387, -1.878, 0.294], Complimnetary Filter : [1.546, -2.088]
# Accelerometer : [-1.761, 8.607] ,  Gyroscope: [1.387, -1.881, 0.291], Complimnetary Filter : [1.541, -2.087]
# Accelerometer : [-1.527, 8.584] ,  Gyroscope: [1.391, -1.882, 0.288], Complimnetary Filter : [1.542, -2.090]
# Accelerometer : [-1.018, 9.198] ,  Gyroscope: [1.382, -1.879, 0.304], Complimnetary Filter : [1.544, -2.090]
# Accelerometer : [-1.310, 8.725] ,  Gyroscope: [1.382, -1.881, 0.307], Complimnetary Filter : [1.537, -2.088]
# Accelerometer : [-1.625, 9.046] ,  Gyroscope: [1.385, -1.881, 0.310], Complimnetary Filter : [1.536, -2.090]
# Accelerometer : [-1.381, 9.136] ,  Gyroscope: [1.388, -1.881, 0.306], Complimnetary Filter : [1.539, -2.090]
# Accelerometer : [-1.311, 9.373] ,  Gyroscope: [1.392, -1.883, 0.299], Complimnetary Filter : [1.542, -2.090]
# Accelerometer : [-1.697, 8.750] ,  Gyroscope: [1.389, -1.882, 0.295], Complimnetary Filter : [1.546, -2.092]
# Accelerometer : [-0.873, 8.850] ,  Gyroscope: [1.391, -1.879, 0.292], Complimnetary Filter : [1.544, -2.091]
# Accelerometer : [-1.239, 8.588] ,  Gyroscope: [1.391, -1.878, 0.291], Complimnetary Filter : [1.546, -2.088]
# Accelerometer : [-1.408, 8.528] ,  Gyroscope: [1.394, -1.877, 0.293], Complimnetary Filter : [1.546, -2.087]
# Accelerometer : [-0.740, 8.356] ,  Gyroscope: [1.396, -1.876, 0.290], Complimnetary Filter : [1.548, -2.086]
# Accelerometer : [-0.824, 8.349] ,  Gyroscope: [1.395, -1.877, 0.289], Complimnetary Filter : [1.551, -2.084]
# Accelerometer : [-0.878, 8.931] ,  Gyroscope: [1.397, -1.879, 0.295], Complimnetary Filter : [1.551, -2.085]
# Accelerometer : [-0.744, 9.448] ,  Gyroscope: [1.399, -1.884, 0.292], Complimnetary Filter : [1.552, -2.088]
# Accelerometer : [-1.797, 9.377] ,  Gyroscope: [1.400, -1.886, 0.292], Complimnetary Filter : [1.555, -2.093]
# Accelerometer : [-0.744, 8.785] ,  Gyroscope: [1.396, -1.891, 0.294], Complimnetary Filter : [1.555, -2.096]
# Accelerometer : [-0.656, 7.857] ,  Gyroscope: [1.401, -1.896, 0.296], Complimnetary Filter : [1.552, -2.101]
# Accelerometer : [-1.318, 8.886] ,  Gyroscope: [1.405, -1.902, 0.304], Complimnetary Filter : [1.556, -2.106]
# Accelerometer : [-0.577, 9.292] ,  Gyroscope: [1.406, -1.905, 0.302], Complimnetary Filter : [1.561, -2.113]
# Accelerometer : [-1.193, 9.246] ,  Gyroscope: [1.402, -1.907, 0.306], Complimnetary Filter : [1.562, -2.117]
# Accelerometer : [-0.820, 9.213] ,  Gyroscope: [1.397, -1.910, 0.303], Complimnetary Filter : [1.558, -2.119]
# Accelerometer : [-0.519, 8.622] ,  Gyroscope: [1.401, -1.910, 0.296], Complimnetary Filter : [1.553, -2.122]
# Accelerometer : [-1.341, 9.071] ,  Gyroscope: [1.402, -1.907, 0.296], Complimnetary Filter : [1.556, -2.122]
# Accelerometer : [-1.226, 9.298] ,  Gyroscope: [1.406, -1.903, 0.294], Complimnetary Filter : [1.558, -2.119]
# Accelerometer : [-1.291, 8.944] ,  Gyroscope: [1.395, -1.890, 0.288], Complimnetary Filter : [1.561, -2.114]
# Accelerometer : [-1.390, 9.006] ,  Gyroscope: [1.393, -1.891, 0.287], Complimnetary Filter : [1.551, -2.102]
# Accelerometer : [-1.145, 9.575] ,  Gyroscope: [1.393, -1.890, 0.285], Complimnetary Filter : [1.548, -2.101]
# Accelerometer : [-1.046, 9.068] ,  Gyroscope: [1.385, -1.890, 0.285], Complimnetary Filter : [1.547, -2.100]
# Accelerometer : [-1.579, 8.598] ,  Gyroscope: [1.386, -1.892, 0.283], Complimnetary Filter : [1.540, -2.101]
# Accelerometer : [-0.655, 9.072] ,  Gyroscope: [1.386, -1.892, 0.283], Complimnetary Filter : [1.540, -2.102]
# Accelerometer : [-1.339, 9.004] ,  Gyroscope: [1.392, -1.894, 0.274], Complimnetary Filter : [1.541, -2.102]
# Accelerometer : [-1.695, 9.808] ,  Gyroscope: [1.396, -1.891, 0.273], Complimnetary Filter : [1.546, -2.104]
# Accelerometer : [-1.099, 9.024] ,  Gyroscope: [1.392, -1.890, 0.274], Complimnetary Filter : [1.550, -2.101]
# Accelerometer : [-1.318, 8.483] ,  Gyroscope: [1.388, -1.890, 0.276], Complimnetary Filter : [1.547, -2.100]
# Accelerometer : [-1.357, 9.286] ,  Gyroscope: [1.386, -1.890, 0.277], Complimnetary Filter : [1.543, -2.100]
# Accelerometer : [-1.876, 8.411] ,  Gyroscope: [1.388, -1.890, 0.273], Complimnetary Filter : [1.541, -2.100]
# Accelerometer : [-0.770, 8.903] ,  Gyroscope: [1.389, -1.892, 0.272], Complimnetary Filter : [1.542, -2.100]
# Accelerometer : [-1.156, 8.880] ,  Gyroscope: [1.386, -1.890, 0.272], Complimnetary Filter : [1.543, -2.102]
# Accelerometer : [-1.146, 9.231] ,  Gyroscope: [1.383, -1.893, 0.269], Complimnetary Filter : [1.540, -2.101]
# Accelerometer : [-1.402, 9.002] ,  Gyroscope: [1.382, -1.894, 0.270], Complimnetary Filter : [1.537, -2.104]
# Accelerometer : [-1.180, 9.493] ,  Gyroscope: [1.378, -1.897, 0.267], Complimnetary Filter : [1.535, -2.105]
# Accelerometer : [-1.261, 9.083] ,  Gyroscope: [1.380, -1.897, 0.259], Complimnetary Filter : [1.532, -2.108]
# Accelerometer : [-1.109, 8.966] ,  Gyroscope: [1.378, -1.897, 0.261], Complimnetary Filter : [1.533, -2.108]
# Accelerometer : [-1.943, 9.257] ,  Gyroscope: [1.378, -1.896, 0.266], Complimnetary Filter : [1.531, -2.108]
# Accelerometer : [-1.076, 9.090] ,  Gyroscope: [1.379, -1.891, 0.264], Complimnetary Filter : [1.532, -2.107]
# Accelerometer : [-1.125, 8.985] ,  Gyroscope: [1.385, -1.893, 0.262], Complimnetary Filter : [1.533, -2.102]
# Accelerometer : [-0.963, 8.795] ,  Gyroscope: [1.388, -1.895, 0.266], Complimnetary Filter : [1.539, -2.103]
# Accelerometer : [-1.227, 8.504] ,  Gyroscope: [1.395, -1.909, 0.274], Complimnetary Filter : [1.543, -2.106]
# Accelerometer : [-1.677, 8.626] ,  Gyroscope: [1.397, -1.910, 0.276], Complimnetary Filter : [1.550, -2.119]
# Accelerometer : [-1.659, 8.945] ,  Gyroscope: [1.399, -1.910, 0.277], Complimnetary Filter : [1.553, -2.122]
# Accelerometer : [-0.864, 9.317] ,  Gyroscope: [1.395, -1.912, 0.276], Complimnetary Filter : [1.553, -2.122]
# Accelerometer : [-1.046, 9.337] ,  Gyroscope: [1.406, -1.918, 0.273], Complimnetary Filter : [1.551, -2.125]
# Accelerometer : [-1.119, 9.280] ,  Gyroscope: [1.408, -1.920, 0.273], Complimnetary Filter : [1.562, -2.131]
# Accelerometer : [-1.608, 9.916] ,  Gyroscope: [1.416, -1.925, 0.282], Complimnetary Filter : [1.565, -2.134]
# Accelerometer : [-0.927, 8.877] ,  Gyroscope: [1.418, -1.931, 0.280], Complimnetary Filter : [1.573, -2.139]
# Accelerometer : [-0.985, 9.466] ,  Gyroscope: [1.420, -1.933, 0.278], Complimnetary Filter : [1.576, -2.145]
# Accelerometer : [-1.358, 8.711] ,  Gyroscope: [1.417, -1.934, 0.278], Complimnetary Filter : [1.577, -2.148]
# Accelerometer : [-0.822, 9.537] ,  Gyroscope: [1.420, -1.936, 0.281], Complimnetary Filter : [1.575, -2.149]
# Accelerometer : [-1.611, 8.729] ,  Gyroscope: [1.424, -1.938, 0.287], Complimnetary Filter : [1.578, -2.151]
# Accelerometer : [-1.746, 9.280] ,  Gyroscope: [1.420, -1.940, 0.289], Complimnetary Filter : [1.581, -2.153]
# Accelerometer : [-0.496, 8.785] ,  Gyroscope: [1.423, -1.943, 0.290], Complimnetary Filter : [1.579, -2.155]
# Accelerometer : [-1.314, 9.097] ,  Gyroscope: [1.424, -1.943, 0.288], Complimnetary Filter : [1.581, -2.158]
# Accelerometer : [-1.060, 9.166] ,  Gyroscope: [1.427, -1.946, 0.289], Complimnetary Filter : [1.582, -2.159]
# Accelerometer : [-1.220, 8.668] ,  Gyroscope: [1.431, -1.949, 0.293], Complimnetary Filter : [1.586, -2.162]
# Accelerometer : [-0.493, 8.686] ,  Gyroscope: [1.433, -1.956, 0.297], Complimnetary Filter : [1.590, -2.166]
# Accelerometer : [-0.737, 8.729] ,  Gyroscope: [1.430, -1.957, 0.299], Complimnetary Filter : [1.592, -2.173]
# Accelerometer : [-1.041, 8.352] ,  Gyroscope: [1.427, -1.958, 0.302], Complimnetary Filter : [1.589, -2.175]
# Accelerometer : [-0.658, 9.248] ,  Gyroscope: [1.427, -1.958, 0.301], Complimnetary Filter : [1.586, -2.176]
# Accelerometer : [-1.520, 9.211] ,  Gyroscope: [1.429, -1.964, 0.306], Complimnetary Filter : [1.586, -2.176]
# Accelerometer : [-0.800, 9.274] ,  Gyroscope: [1.434, -1.965, 0.305], Complimnetary Filter : [1.588, -2.182]
# Accelerometer : [-1.644, 8.865] ,  Gyroscope: [1.434, -1.964, 0.297], Complimnetary Filter : [1.593, -2.183]
# Accelerometer : [-1.821, 9.009] ,  Gyroscope: [1.429, -1.967, 0.306], Complimnetary Filter : [1.592, -2.182]
# Accelerometer : [-0.932, 8.816] ,  Gyroscope: [1.430, -1.968, 0.311], Complimnetary Filter : [1.588, -2.185]
# Accelerometer : [-0.740, 9.351] ,  Gyroscope: [1.418, -1.972, 0.321], Complimnetary Filter : [1.588, -2.187]
# Accelerometer : [-1.520, 8.860] ,  Gyroscope: [1.416, -1.973, 0.325], Complimnetary Filter : [1.576, -2.191]
# Accelerometer : [-1.044, 8.510] ,  Gyroscope: [1.416, -1.973, 0.327], Complimnetary Filter : [1.574, -2.192]
# Accelerometer : [-0.662, 8.681] ,  Gyroscope: [1.409, -1.978, 0.313], Complimnetary Filter : [1.573, -2.193]
# Accelerometer : [-1.228, 9.125] ,  Gyroscope: [1.407, -1.978, 0.313], Complimnetary Filter : [1.566, -2.198]
# Accelerometer : [-1.155, 9.190] ,  Gyroscope: [1.406, -1.978, 0.313], Complimnetary Filter : [1.563, -2.198]
# Accelerometer : [-0.634, 9.162] ,  Gyroscope: [1.397, -1.984, 0.323], Complimnetary Filter : [1.562, -2.199]
# Accelerometer : [-1.259, 8.772] ,  Gyroscope: [1.394, -1.985, 0.324], Complimnetary Filter : [1.553, -2.204]
# Accelerometer : [-0.924, 8.582] ,  Gyroscope: [1.398, -1.984, 0.326], Complimnetary Filter : [1.550, -2.205]
# Accelerometer : [-1.122, 8.910] ,  Gyroscope: [1.398, -1.984, 0.319], Complimnetary Filter : [1.553, -2.205]
# Accelerometer : [-2.086, 8.399] ,  Gyroscope: [1.396, -1.988, 0.321], Complimnetary Filter : [1.553, -2.205]
# Accelerometer : [-0.956, 8.787] ,  Gyroscope: [1.397, -1.992, 0.325], Complimnetary Filter : [1.552, -2.209]
# Accelerometer : [-1.365, 8.538] ,  Gyroscope: [1.395, -1.991, 0.324], Complimnetary Filter : [1.552, -2.213]
# Accelerometer : [-1.211, 8.665] ,  Gyroscope: [1.397, -1.990, 0.329], Complimnetary Filter : [1.551, -2.212]
# Accelerometer : [-0.857, 9.453] ,  Gyroscope: [1.401, -1.998, 0.329], Complimnetary Filter : [1.553, -2.212]
# Accelerometer : [-1.073, 8.199] ,  Gyroscope: [1.402, -1.997, 0.328], Complimnetary Filter : [1.557, -2.219]
# Accelerometer : [-0.852, 9.457] ,  Gyroscope: [1.402, -1.997, 0.327], Complimnetary Filter : [1.558, -2.219]
# Accelerometer : [-0.771, 8.646] ,  Gyroscope: [1.404, -1.998, 0.327], Complimnetary Filter : [1.558, -2.219]
# Accelerometer : [-0.851, 8.801] ,  Gyroscope: [1.405, -1.997, 0.325], Complimnetary Filter : [1.560, -2.219]
# Accelerometer : [-1.210, 9.033] ,  Gyroscope: [1.407, -1.997, 0.326], Complimnetary Filter : [1.561, -2.219]
# Accelerometer : [-1.515, 8.831] ,  Gyroscope: [1.411, -2.004, 0.335], Complimnetary Filter : [1.564, -2.220]
# Accelerometer : [-1.151, 8.704] ,  Gyroscope: [1.412, -2.005, 0.329], Complimnetary Filter : [1.568, -2.226]
# Accelerometer : [-0.327, 8.610] ,  Gyroscope: [1.414, -2.009, 0.330], Complimnetary Filter : [1.569, -2.228]
# Accelerometer : [-1.121, 9.191] ,  Gyroscope: [1.421, -2.008, 0.325], Complimnetary Filter : [1.571, -2.231]
# Accelerometer : [-1.202, 9.320] ,  Gyroscope: [1.420, -2.011, 0.324], Complimnetary Filter : [1.578, -2.231]
# Accelerometer : [-0.436, 8.957] ,  Gyroscope: [1.426, -2.012, 0.325], Complimnetary Filter : [1.578, -2.234]
# Accelerometer : [-2.031, 9.400] ,  Gyroscope: [1.425, -2.012, 0.324], Complimnetary Filter : [1.584, -2.235]
# Accelerometer : [-1.531, 9.883] ,  Gyroscope: [1.427, -2.013, 0.324], Complimnetary Filter : [1.584, -2.235]
# Accelerometer : [-1.550, 9.170] ,  Gyroscope: [1.429, -2.015, 0.326], Complimnetary Filter : [1.585, -2.237]
# Accelerometer : [-0.930, 8.955] ,  Gyroscope: [1.428, -2.016, 0.326], Complimnetary Filter : [1.588, -2.239]
# Accelerometer : [-1.675, 8.537] ,  Gyroscope: [1.428, -2.016, 0.328], Complimnetary Filter : [1.587, -2.240]
# Accelerometer : [-1.810, 9.515] ,  Gyroscope: [1.428, -2.016, 0.329], Complimnetary Filter : [1.586, -2.240]
# Accelerometer : [-1.019, 9.046] ,  Gyroscope: [1.427, -2.015, 0.326], Complimnetary Filter : [1.586, -2.240]
# Accelerometer : [-1.039, 8.768] ,  Gyroscope: [1.431, -2.016, 0.321], Complimnetary Filter : [1.586, -2.240]
# Accelerometer : [-1.449, 9.723] ,  Gyroscope: [1.428, -2.018, 0.335], Complimnetary Filter : [1.590, -2.240]

# %%
print(len(imu_results))
# Out:
# 1000

# %%
print((float(imu_results[-1])-float(imu_results[0]))/1000)
# Out:
# 2.635
# 2025-02-10 21:38:54,508 | INFO     |: Disconnected from A1C0DD95-B611-6CFA-AF80-6BCF50487F59

# %%
print(len(imu_results))
# Out:
# 1677

# %%
print((float(imu_results[-1])-float(imu_results[0]))/1000)
# Out:
# 5.003
# 2025-02-10 22:28:49,096 | INFO     |: Disconnected from A1C0DD95-B611-6CFA-AF80-6BCF50487F59
